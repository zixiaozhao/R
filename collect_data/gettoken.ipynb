# %% [markdown]
# ## Tree-sitter Token & Identifier Extraction Toolkit
#
# This notebook cell implements a small utility library that uses **Tree-sitter** to parse source code in multiple languages (e.g., R, Python, C-style) and extract:
#
# 1. **All code tokens** (keywords, literals, identifiers, punctuation).
# 2. **Only identifiers** (variable names, function names, etc.).

# %%
from tree_sitter import Language, Parser
import re
from io import StringIO
import tokenize
import os
import jsonlines
import csv
import re
from typing import List

DOCSTRING_REGEX_TOKENIZER = re.compile(r"[^\s,'\"`.():\[\]=*;>{\}+-/\\]+|\\+|\.+|\(\)|{\}|\[\]|\(+|\)+|:+|\[+|\]+|{+|\}+|=+|\*+|;+|>+|\++|-+|/+")


def tokenize_docstring(docstring: str) -> List[str]:
    return [t for t in DOCSTRING_REGEX_TOKENIZER.findall(docstring) if t is not None and len(t) > 0]


Language.build_library(
  # Store the library in the `build` directory
  'build/my-languages.so',

  # Include one or more languages
  [
    'tree-sitter-r' 
  ]
)

r = Language('build/my-languages.so', 'r')
parser = Parser()
def remove_comments_and_docstrings(source, lang):
    if lang in ['python']:
        """
        Returns 'source' minus comments and docstrings.
        """
        io_obj = StringIO(source)
        out = ""
        prev_toktype = tokenize.INDENT
        last_lineno = -1
        last_col = 0
        for tok in tokenize.generate_tokens(io_obj.readline):
            token_type = tok[0]
            token_string = tok[1]
            start_line, start_col = tok[2]
            end_line, end_col = tok[3]
            ltext = tok[4]
            if start_line > last_lineno:
                last_col = 0
            if start_col > last_col:
                out += (" " * (start_col - last_col))
            # Remove comments:
            if token_type == tokenize.COMMENT:
                pass
            # This series of conditionals removes docstrings:
            elif token_type == tokenize.STRING:
                if prev_toktype != tokenize.INDENT:
                    # This is likely a docstring; double-check we're not inside an operator:
                    if prev_toktype != tokenize.NEWLINE:
                        if start_col > 0:
                            out += token_string
            else:
                out += token_string
            prev_toktype = token_type
            last_col = end_col
            last_lineno = end_line
        temp = []
        for x in out.split('\n'):
            if x.strip() != "":
                temp.append(x)
        return '\n'.join(temp)
    elif lang in ['ruby']:
        return source
    else:
        def replacer(match):
            s = match.group(0)
            if s.startswith('/'):
                return " "  # note: a space and not an empty string
            else:
                return s

        pattern = re.compile(
            r'//.*?$|/\*.*?\*/|\'(?:\\.|[^\\\'])*\'|"(?:\\.|[^\\"])*"',
            re.DOTALL | re.MULTILINE
        )
        temp = []
        for x in re.sub(pattern, replacer, source).split('\n'):
            if x.strip() != "":
                temp.append(x)
        return '\n'.join(temp)
    
def tree_to_token_index(root_node):
    if (len(root_node.children) == 0 or root_node.type in ['string_literal', 'string', 'character_literal']):
        return [(root_node.start_point, root_node.end_point, root_node.type)]
    else:
        code_tokens = []
        for child in root_node.children:
            code_tokens += tree_to_token_index(child)
        return code_tokens


def tree_to_variable_index(root_node, index_to_code):
    if (len(root_node.children) == 0 or root_node.type in ['string_literal', 'string',
                                                           'character_literal']) and root_node.type != 'comment':
        index = (root_node.start_point, root_node.end_point)
        _, code = index_to_code[index]
        if root_node.type != code:
            return [(root_node.start_point, root_node.end_point)]
        else:
            return []
    else:
        code_tokens = []
        for child in root_node.children:
            code_tokens += tree_to_variable_index(child, index_to_code)
        return code_tokens

def index_to_code_token(index, code):
    start_point = index[0]
    end_point = index[1]
    if start_point[0] == end_point[0]:
        s = code[start_point[0]][start_point[1]:end_point[1]]
    else:
        s = ""
        s += code[start_point[0]][start_point[1]:]
        for i in range(start_point[0] + 1, end_point[0]):
            s += code[i]
        s += code[end_point[0]][:end_point[1]]
    return s

def get_type(parser, code, lang):
    parser.set_language(lang)
    tree = parser.parse(bytes(code, 'utf8'))
    root_node = tree.root_node
    tokens_index = tree_to_token_index(root_node)
    code = code.split('\n')
    code_tokens = [index_to_code_token(x, code) for x in tokens_index]
    index_to_code = {}
    for (index, code) in zip(tokens_index, code_tokens):
        index_to_code[index] = code
    return index_to_code

def get_identifiers(parser, code, lang):
    parser.set_language(lang)
    code = remove_comments_and_docstrings(code,lang)
    tree = parser.parse(bytes(code, 'utf8'))
    root_node = tree.root_node
    tokens_index = tree_to_token_index(root_node)
    code = code.split('\n')
    code_tokens = [index_to_code_token(x, code) for x in tokens_index]
    index_to_code = {}
    for (index, code) in zip(tokens_index, code_tokens):
        if(index[2]=='identifier'):
            index_to_code[index] = code
    return index_to_code

# %%
code_set = [
    ("""
    html_extras_for_document <- function(knit_meta, runtime, dependency_resolver,
                                        format_deps = NULL) {
    """, r),
]

# %%
import pprint
for code, lang in code_set:
    print('*'*100)
    print("Original Code")
    print(code)
    print("_"*100)
    print("Parsed Identifiers")
    pprint.pprint(get_type(parser, code, lang))
    print('*'*100)
# Out:
# ****************************************************************************************************
# Original Code
#
#     html_extras_for_document <- function(knit_meta, runtime, dependency_resolver,
#                                         format_deps = NULL) {
#
# ____________________________________________________________________________________________________
# Parsed Identifiers
# {((1, 4), (1, 28), 'identifier'): 'html_extras_for_document',
#  ((1, 29), (1, 31), '<-'): '<-',
#  ((1, 32), (1, 40), 'function'): 'function',
#  ((1, 40), (1, 41), '('): '(',
#  ((1, 41), (1, 50), 'identifier'): 'knit_meta',
#  ((1, 50), (1, 51), ','): ',',
#  ((1, 52), (1, 59), 'identifier'): 'runtime',
#  ((1, 59), (1, 60), ','): ',',
#  ((1, 61), (1, 80), 'identifier'): 'dependency_resolver',
#  ((1, 80), (1, 81), ','): ',',
#  ((2, 40), (2, 51), 'identifier'): 'format_deps',
#  ((2, 52), (2, 53), '='): '=',
#  ((2, 54), (2, 58), 'null'): 'NULL',
#  ((2, 58), (2, 59), ')'): ')',
#  ((2, 60), (2, 61), '{'): '{',
#  ((2, 61), (2, 61), '}'): '',
#  ((2, 61), (3, 0), '\n'): ''}
# ****************************************************************************************************

# %% [markdown]
# ### Extract & Count R Functions, then Aggregate Final Metadata
#
# This cell reads the intermediate `MetaData.csv`, walks through each R package repository, extracts all function definitions (with their code tokens and associated documentation), and writes the enriched summary into `MetaData_final.csv`.
#
# **Steps performed:**
# 1. **Open CSV files**
#    - Read from `MetaData.csv` (existing repo metadata).
#    - Append to `MetaData_final.csv`, adding a new column `# of function`.
#
# 2. **Iterate over each repository**
#    - Construct the package root folder (`<repo>/`) and the `man/` docs directory.
#    - Skip any repo if `functions.jsonl` already exists (to avoid re-processing).
#
# 3. **Parse each documentation file in `man/`**
#    - **Identify source R files** via lines containing `"% Please edit documentation in R/<file>.r"`.
#    - **Collect all declared names** (`\name{…}` and `\alias{…}`) that indicate documented objects.
#    - **Accumulate the “description” text** inside `\description{…}` or `\details{…}` blocks.
#
# 4. **For each referenced R source file**
#    - Read the code and tokenize it using `get_type(parser, code, r)` (Tree-sitter).
#    - **Detect function definitions** by scanning tokens:
#      - Look for the pattern `(identifier) <- function` or `(identifier) = function`.
#      - Once found, collect all subsequent tokens until the matching `}` closes the function body.
#    - **Write each function** as a JSON entry in `functions.jsonl`, including:
#      - `repo` name
#      - `func_name`
#      - `code_tokens` (list of tokens in the function body)
#      - `docstring` (raw description text)
#      - `docstring_tokens` (tokenized description via `tokenize_docstring`)
#
# 5. **Count functions & record results**
#    - Keep a per-repo counter of extracted functions.
#    - After processing all docs, append one row to `MetaData_final.csv` with all original metadata plus the final function count.

# %%
with open("MetaData.csv", "r") as metaData, open("MetaData_final.csv", "a+", newline="") as f1:
    writer1 = csv.writer(f1)
    writer1.writerow(["id", "repo", "html_url","owner_login", "contents_url", "created_at", "last_commit", "contributor_count","language", "star_count", "forks_count", "tidy", "# of R file", "# of function"])
    reader = csv.reader(metaData)
    next(reader)
    for row in reader:
        file_path = "" + row[1]+ '/'
        rdpath = file_path + 'man/'
        count = 0
        if os.path.exists(file_path+'functions.jsonl'):
            continue
        for file in os.listdir(rdpath):
            print(rdpath+file)
            with open(rdpath+file, 'r') as rd:
                names = []
                document = ''
                flag = False
                Rfilename = []
                for lines in rd:
                    if lines.__contains__(r'% Please edit documentation in R/'):
                        d = re.split(r'\s+', lines)
                        for item in d:
                            if item.__contains__(r'.r') or item.__contains__(r'.R'):
                                Rfilename.append(item.replace('R/','').replace(',','').replace('\n',''))
                    if lines.__contains__(r'\name{'):
                        names.append(lines[6:-2])
                    if lines.__contains__(r'\alias{'):
                        names.append(lines[7:-2])
                    if lines.__contains__(r'\description{') or lines.__contains__(r'\details{'):
                        flag = True
                        continue
                    if lines=='}\n':
                        flag = False
                    if flag:
                        document = document + lines.replace('\n', ' ')

                print(Rfilename)
                print(names)
                for name in Rfilename:
                    Rfile = open(file_path+name).read()
                    tokens = get_type(parser, Rfile, r)
                    fname = ''
                    code = []
                    t1 = None
                    t2 = None
                    t3 = None
                    c1 = None
                    c2 = None
                    c3 = None
                    codeF = False
                    c = 0
                    isChanged = False
                    for key, value in tokens.items():
                        t1 = t2
                        t2 = t3
                        t3 = key[2]
                        c1 = c2
                        c2 = c3
                        c3 = value
                        if t1 == 'identifier' and c1 in names and (t2 == '<-' or t2 == '=') and t3 == 'function':
                            codeF = True
                            fname = c1
                        if codeF:
                            code.append(value)
                            if value == '{':
                                c += 1
                                isChanged = True
                            if value == '}':
                                c -= 1

                            if c == 0 and isChanged:
                                with jsonlines.open(file_path+'functions.jsonl', mode='a') as writer:
                                    json = {'repo':row[1],'func_name':fname, 'code_tokens':code, 'docstring':document,'docstring_tokens':tokenize_docstring(document)}
                                    writer.write(json)
                                    count += 1
                                code = []
                                codeF = False
                                c = 0
                                isChanged = False
        writer1.writerow([row[0], row[1], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[9], row[10], row[11], row[12], count])
# Out:
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/callr_args_default.Rd
# ['utils_callr.R']
# ['callr_args_default', 'callr_args_default']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/reexports.Rd
# ['tar_tidyselect.R']
# ['reexports', 'reexports', 'all_of', 'any_of', 'contains', 'ends_with', 'everything', 'last_col', 'matches', 'num_range', 'one_of', 'starts_with']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/rstudio_addin_tar_glimpse.Rd
# ['rstudio_addin_tar_glimpse.R']
# ['rstudio_addin_tar_glimpse', 'rstudio_addin_tar_glimpse']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/rstudio_addin_tar_load.Rd
# ['rstudio_addin_tar_load.R']
# ['rstudio_addin_tar_load', 'rstudio_addin_tar_load']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/rstudio_addin_tar_make_bg.Rd
# ['rstudio_addin_tar_make_bg.R']
# ['rstudio_addin_tar_make_bg', 'rstudio_addin_tar_make_bg']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/rstudio_addin_tar_outdated.Rd
# ['rstudio_addin_tar_outdated.R']
# ['rstudio_addin_tar_outdated', 'rstudio_addin_tar_outdated']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/rstudio_addin_tar_progress.Rd
# ['rstudio_addin_tar_progress.R']
# ['rstudio_addin_tar_progress', 'rstudio_addin_tar_progress']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/rstudio_addin_tar_read.Rd
# ['rstudio_addin_tar_read.R']
# ['rstudio_addin_tar_read', 'rstudio_addin_tar_read']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/rstudio_addin_tar_target.Rd
# ['rstudio_addin_tar_target.R']
# ['rstudio_addin_tar_target', 'rstudio_addin_tar_target']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/rstudio_addin_tar_visnetwork.Rd
# ['rstudio_addin_tar_visnetwork.R']
# ['rstudio_addin_tar_visnetwork', 'rstudio_addin_tar_visnetwork']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/targets-package.Rd
# ['tar_package.R']
# ['targets-package', 'targets-package']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/target_run_worker.Rd
# ['class_target.R']
# ['target_run_worker', 'target_run_worker']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_active.Rd
# ['tar_active.R']
# ['tar_active', 'tar_active']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_assert.Rd
# ['utils_assert.R']
# ['tar_assert', 'tar_assert', 'tar_assert_chr', 'tar_assert_dbl', 'tar_assert_df', 'tar_assert_equal_lengths', 'tar_assert_envir', 'tar_assert_expr', 'tar_assert_flag', 'tar_assert_file', 'tar_assert_finite', 'tar_assert_function', 'tar_assert_function_arguments', 'tar_assert_ge', 'tar_assert_identical', 'tar_assert_in', 'tar_assert_not_dirs', 'tar_assert_not_dir', 'tar_assert_not_in', 'tar_assert_inherits', 'tar_assert_int', 'tar_assert_internet', 'tar_assert_lang', 'tar_assert_le', 'tar_assert_list', 'tar_assert_lgl', 'tar_assert_name', 'tar_assert_named', 'tar_assert_names', 'tar_assert_nonempty', 'tar_assert_not_expr', 'tar_assert_nzchar', 'tar_assert_package', 'tar_assert_path', 'tar_assert_match', 'tar_assert_nonmissing', 'tar_assert_positive', 'tar_assert_scalar', 'tar_assert_store', 'tar_assert_target', 'tar_assert_target_list', 'tar_assert_true', 'tar_assert_unique', 'tar_assert_unique_targets']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_as_pipeline.Rd
# ['class_pipeline.R']
# ['tar_as_pipeline', 'tar_as_pipeline']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_backoff.Rd
# ['tar_backoff.R']
# ['tar_backoff', 'tar_backoff']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_bind.Rd
# ['tar_bind.R']
# ['tar_bind', 'tar_bind']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_branches.Rd
# ['tar_branches.R']
# ['tar_branches', 'tar_branches']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_branch_index.Rd
# ['tar_branch_index.R']
# ['tar_branch_index', 'tar_branch_index']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_branch_names.Rd
# ['tar_branch_names.R']
# ['tar_branch_names', 'tar_branch_names']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_branch_names_raw.Rd
# ['tar_branch_names_raw.R']
# ['tar_branch_names_raw', 'tar_branch_names_raw']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_built.Rd
# ['tar_built.R']
# ['tar_built', 'tar_built']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_call.Rd
# ['tar_call.R']
# ['tar_call', 'tar_call']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_callr_args_default.Rd
# ['utils_callr.R']
# ['tar_callr_args_default', 'tar_callr_args_default']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_callr_inner_try.Rd
# ['utils_callr.R']
# ['tar_callr_inner_try', 'tar_callr_inner_try']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_cancel.Rd
# ['tar_cancel.R']
# ['tar_cancel', 'tar_cancel']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_canceled.Rd
# ['tar_canceled.R']
# ['tar_canceled', 'tar_canceled']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_condition.Rd
# ['utils_condition.R']
# ['tar_condition', 'tar_condition', 'tar_message_run', 'tar_throw_file', 'tar_throw_run', 'tar_throw_validate', 'tar_warn_deprecate', 'tar_warn_run', 'tar_warn_validate', 'tar_error', 'tar_warning', 'tar_message']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_config_get.Rd
# ['tar_config_get.R']
# ['tar_config_get', 'tar_config_get']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_config_set.Rd
# ['tar_config_set.R']
# ['tar_config_set', 'tar_config_set']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_config_unset.Rd
# ['tar_config_unset.R']
# ['tar_config_unset', 'tar_config_unset']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_counter.Rd
# ['class_counter.R']
# ['tar_counter', 'tar_counter']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_crew.Rd
# ['tar_crew.R']
# ['tar_crew', 'tar_crew']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_cue.Rd
# ['tar_cue.R']
# ['tar_cue', 'tar_cue']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_debug_instructions.Rd
# ['tar_debug_instructions.R']
# ['tar_debug_instructions', 'tar_debug_instructions']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_deduplicate.Rd
# ['tar_deduplicate.R']
# ['tar_deduplicate', 'tar_deduplicate']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_definition.Rd
# ['tar_definition.R']
# ['tar_definition', 'tar_definition']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_delete.Rd
# ['tar_delete.R']
# ['tar_delete', 'tar_delete']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_deps.Rd
# ['tar_deps.R']
# ['tar_deps', 'tar_deps']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_deps_raw.Rd
# ['tar_deps_raw.R']
# ['tar_deps_raw', 'tar_deps_raw']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_destroy.Rd
# ['tar_destroy.R']
# ['tar_destroy', 'tar_destroy']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_dir.Rd
# ['tar_dir.R']
# ['tar_dir', 'tar_dir']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_edit.Rd
# ['tar_edit.R']
# ['tar_edit', 'tar_edit']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_engine_knitr.Rd
# ['tar_engine_knitr.R']
# ['tar_engine_knitr', 'tar_engine_knitr']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_envir.Rd
# ['tar_envir.R']
# ['tar_envir', 'tar_envir']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_envvars.Rd
# ['tar_envvars.R']
# ['tar_envvars', 'tar_envvars']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_errored.Rd
# ['tar_errored.R']
# ['tar_errored', 'tar_errored']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_exist_meta.Rd
# ['tar_exist_meta.R']
# ['tar_exist_meta', 'tar_exist_meta']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_exist_objects.Rd
# ['tar_exist_objects.R']
# ['tar_exist_objects', 'tar_exist_objects']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_exist_process.Rd
# ['tar_exist_process.R']
# ['tar_exist_process', 'tar_exist_process']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_exist_progress.Rd
# ['tar_exist_progress.R']
# ['tar_exist_progress', 'tar_exist_progress']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_exist_script.Rd
# ['tar_exist_script.R']
# ['tar_exist_script', 'tar_exist_script']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_format.Rd
# ['tar_format.R']
# ['tar_format', 'tar_format']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_github_actions.Rd
# ['tar_github_actions.R']
# ['tar_github_actions', 'tar_github_actions']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_glimpse.Rd
# ['tar_glimpse.R']
# ['tar_glimpse', 'tar_glimpse']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_group.Rd
# ['tar_group.R']
# ['tar_group', 'tar_group']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_helper.Rd
# ['tar_helper.R']
# ['tar_helper', 'tar_helper']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_helper_raw.Rd
# ['tar_helper_raw.R']
# ['tar_helper_raw', 'tar_helper_raw']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_interactive.Rd
# ['tar_interactive.R']
# ['tar_interactive', 'tar_interactive']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_invalidate.Rd
# ['tar_invalidate.R']
# ['tar_invalidate', 'tar_invalidate']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_language.Rd
# ['utils_language.R']
# ['tar_language', 'tar_language', 'tar_deparse_language', 'tar_deparse_safe', 'tar_tidy_eval', 'tar_tidyselect_eval']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_load.Rd
# ['tar_load.R']
# ['tar_load', 'tar_load']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_load_everything.Rd
# ['tar_load_everything.R']
# ['tar_load_everything', 'tar_load_everything']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_load_globals.Rd
# ['tar_load_globals.R']
# ['tar_load_globals', 'tar_load_globals']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_load_raw.Rd
# ['tar_load_raw.R']
# ['tar_load_raw', 'tar_load_raw']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_make.Rd
# ['tar_make.R']
# ['tar_make', 'tar_make']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_make_clustermq.Rd
# ['tar_make_clustermq.R']
# ['tar_make_clustermq', 'tar_make_clustermq']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_make_future.Rd
# ['tar_make_future.R']
# ['tar_make_future', 'tar_make_future']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_make_interactive.Rd
# ['tar_make_interactive.R']
# ['tar_make_interactive', 'tar_make_interactive']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_manifest.Rd
# ['tar_manifest.R']
# ['tar_manifest', 'tar_manifest']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_mermaid.Rd
# ['tar_mermaid.R']
# ['tar_mermaid', 'tar_mermaid']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_meta.Rd
# ['tar_meta.R']
# ['tar_meta', 'tar_meta']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_name.Rd
# ['tar_name.R']
# ['tar_name', 'tar_name']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_network.Rd
# ['tar_network.R']
# ['tar_network', 'tar_network']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_newer.Rd
# ['tar_newer.R']
# ['tar_newer', 'tar_newer']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_noninteractive.Rd
# ['tar_noninteractive.R']
# ['tar_noninteractive', 'tar_noninteractive']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_objects.Rd
# ['tar_objects.R']
# ['tar_objects', 'tar_objects']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_older.Rd
# ['tar_older.R']
# ['tar_older', 'tar_older']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_option_get.Rd
# ['tar_option_get.R']
# ['tar_option_get', 'tar_option_get']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_option_reset.Rd
# ['tar_option_reset.R']
# ['tar_option_reset', 'tar_option_reset']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_option_set.Rd
# ['tar_option_set.R']
# ['tar_option_set', 'tar_option_set']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_outdated.Rd
# ['tar_outdated.R']
# ['tar_outdated', 'tar_outdated']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_path.Rd
# ['tar_path.R']
# ['tar_path', 'tar_path']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_path_objects_dir.Rd
# ['utils_path.R']
# ['tar_path_objects_dir', 'tar_path_objects_dir']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_path_objects_dir_cloud.Rd
# ['utils_path.R']
# ['tar_path_objects_dir_cloud', 'tar_path_objects_dir_cloud']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_path_script.Rd
# ['tar_path_script.R']
# ['tar_path_script', 'tar_path_script']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_path_script_support.Rd
# ['tar_path_script_support.R']
# ['tar_path_script_support', 'tar_path_script_support']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_path_store.Rd
# ['tar_path_store.R']
# ['tar_path_store', 'tar_path_store']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_path_target.Rd
# ['tar_path_target.R']
# ['tar_path_target', 'tar_path_target']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_pattern.Rd
# ['tar_pattern.R']
# ['tar_pattern', 'tar_pattern', 'map', 'cross', 'head', 'tail', 'sample']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_pid.Rd
# ['tar_pid.R']
# ['tar_pid', 'tar_pid']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_pipeline.Rd
# ['tar_pipeline.R']
# ['tar_pipeline', 'tar_pipeline']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_pipeline_validate_lite.Rd
# ['class_pipeline.R']
# ['tar_pipeline_validate_lite', 'tar_pipeline_validate_lite']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_poll.Rd
# ['tar_poll.R']
# ['tar_poll', 'tar_poll']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_process.Rd
# ['tar_process.R']
# ['tar_process', 'tar_process']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_progress.Rd
# ['tar_progress.R']
# ['tar_progress', 'tar_progress']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_progress_branches.Rd
# ['tar_progress_branches.R']
# ['tar_progress_branches', 'tar_progress_branches']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_progress_summary.Rd
# ['tar_progress_summary.R']
# ['tar_progress_summary', 'tar_progress_summary']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_prune.Rd
# ['tar_prune.R']
# ['tar_prune', 'tar_prune']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_random_name.Rd
# ['utils_data.R']
# ['tar_random_name', 'tar_random_name']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_random_port.Rd
# ['tar_random_port.R', 'utils_url.R']
# ['tar_random_port', 'tar_random_port']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_read.Rd
# ['tar_read.R']
# ['tar_read', 'tar_read']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_read_raw.Rd
# ['tar_read_raw.R']
# ['tar_read_raw', 'tar_read_raw']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_renv.Rd
# ['tar_renv.R']
# ['tar_renv', 'tar_renv']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_reprex.Rd
# ['tar_reprex.R']
# ['tar_reprex', 'tar_reprex']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources.Rd
# ['tar_resources.R']
# ['tar_resources', 'tar_resources']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_aws.Rd
# ['tar_resources_aws.R']
# ['tar_resources_aws', 'tar_resources_aws']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_clustermq.Rd
# ['tar_resources_clustermq.R']
# ['tar_resources_clustermq', 'tar_resources_clustermq']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_crew.Rd
# ['tar_resources_crew.R']
# ['tar_resources_crew', 'tar_resources_crew']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_feather.Rd
# ['tar_resources_feather.R']
# ['tar_resources_feather', 'tar_resources_feather']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_fst.Rd
# ['tar_resources_fst.R']
# ['tar_resources_fst', 'tar_resources_fst']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_future.Rd
# ['tar_resources_future.R']
# ['tar_resources_future', 'tar_resources_future']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_gcp.Rd
# ['tar_resources_gcp.R']
# ['tar_resources_gcp', 'tar_resources_gcp']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_network.Rd
# ['tar_resources_network.R']
# ['tar_resources_network', 'tar_resources_network']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_parquet.Rd
# ['tar_resources_parquet.R']
# ['tar_resources_parquet', 'tar_resources_parquet']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_qs.Rd
# ['tar_resources_qs.R']
# ['tar_resources_qs', 'tar_resources_qs']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_resources_url.Rd
# ['tar_resources_url.R']
# ['tar_resources_url', 'tar_resources_url']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_runtime_object.Rd
# ['class_runtime.R']
# ['tar_runtime_object', 'tar_runtime_object']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_script.Rd
# ['tar_script.R']
# ['tar_script', 'tar_script']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_seed.Rd
# ['tar_seed.R']
# ['tar_seed', 'tar_seed']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_sitrep.Rd
# ['tar_sitrep.R']
# ['tar_sitrep', 'tar_sitrep']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_skipped.Rd
# ['tar_skipped.R']
# ['tar_skipped', 'tar_skipped']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_source.Rd
# ['tar_source.R']
# ['tar_source', 'tar_source']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_started.Rd
# ['tar_started.R']
# ['tar_started', 'tar_started']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_store.Rd
# ['tar_store.R']
# ['tar_store', 'tar_store']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_target.Rd
# ['tar_target.R']
# ['tar_target', 'tar_target']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_target_raw.Rd
# ['tar_target_raw.R']
# ['tar_target_raw', 'tar_target_raw']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_test.Rd
# ['tar_test.R']
# ['tar_test', 'tar_test']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_timestamp.Rd
# ['tar_timestamp.R']
# ['tar_timestamp', 'tar_timestamp']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_timestamp_raw.Rd
# ['tar_timestamp_raw.R']
# ['tar_timestamp_raw', 'tar_timestamp_raw']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_toggle.Rd
# ['tar_toggle.R']
# ['tar_toggle', 'tar_toggle']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_traceback.Rd
# ['tar_traceback.R']
# ['tar_traceback', 'tar_traceback']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_unscript.Rd
# ['tar_unscript.R']
# ['tar_unscript', 'tar_unscript']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_validate.Rd
# ['tar_validate.R']
# ['tar_validate', 'tar_validate']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_visnetwork.Rd
# ['tar_visnetwork.R']
# ['tar_visnetwork', 'tar_visnetwork']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_watch.Rd
# ['tar_watch.R']
# ['tar_watch', 'tar_watch']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_watch_app_ui.Rd
# ['tar_watch.R']
# ['tar_watch_app_ui', 'tar_watch_app_ui']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_watch_server.Rd
# ['tar_watch_server.R']
# ['tar_watch_server', 'tar_watch_server']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_watch_ui.Rd
# ['tar_watch_ui.R']
# ['tar_watch_ui', 'tar_watch_ui']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_workspace.Rd
# ['tar_workspace.R']
# ['tar_workspace', 'tar_workspace']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/tar_workspaces.Rd
# ['tar_workspaces.R']
# ['tar_workspaces', 'tar_workspaces']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/use_targets.Rd
# ['use_targets.R']
# ['use_targets', 'use_targets']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/use_targets_rmd.Rd
# ['use_targets_rmd.R']
# ['use_targets_rmd', 'use_targets_rmd']
# C:/Users/shawn/Desktop/R/R/ropensci/targets/man/use_targets_scheduler.Rd
# ['use_targets.R']
# ['use_targets_scheduler', 'use_targets_scheduler']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/align.Rd
# ['weighted_hist.R']
# ['align', 'align', 'align_none', 'align_boundary', 'align_center']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/automatic-partial-functions.Rd
# ['auto_partial.R']
# ['automatic-partial-functions', 'automatic-partial-functions']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/bandwidth.Rd
# ['density.R']
# ['bandwidth', 'bandwidth', 'bandwidth_nrd0', 'bandwidth_nrd', 'bandwidth_ucv', 'bandwidth_bcv', 'bandwidth_SJ', 'bandwidth_dpi']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/bin_dots.Rd
# ['binning_methods.R']
# ['bin_dots', 'bin_dots']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/bounder_cdf.Rd
# ['bounder.R']
# ['bounder_cdf', 'bounder_cdf']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/bounder_cooke.Rd
# ['bounder.R']
# ['bounder_cooke', 'bounder_cooke']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/bounder_range.Rd
# ['bounder.R']
# ['bounder_range', 'bounder_range']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/breaks.Rd
# ['weighted_hist.R']
# ['breaks', 'breaks', 'breaks_fixed', 'breaks_Sturges', 'breaks_Scott', 'breaks_FD']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/curve_interval.Rd
# ['curve_interval.R']
# ['curve_interval', 'curve_interval', 'curve_interval.matrix', 'curve_interval.rvar', 'curve_interval.data.frame']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/cut_cdf_qi.Rd
# ['cut_cdf_qi.R']
# ['cut_cdf_qi', 'cut_cdf_qi']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/density_bounded.Rd
# ['density.R']
# ['density_bounded', 'density_bounded']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/density_histogram.Rd
# ['density.R']
# ['density_histogram', 'density_histogram']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/density_unbounded.Rd
# ['density.R']
# ['density_unbounded', 'density_unbounded']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/find_dotplot_binwidth.Rd
# ['binning_methods.R']
# ['find_dotplot_binwidth', 'find_dotplot_binwidth']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/geom_dots.Rd
# ['geom_dotsinterval.R']
# ['geom_dots', 'geom_dots']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/geom_dotsinterval.Rd
# ['geom_dotsinterval.R']
# ['geom_dotsinterval', 'geom_dotsinterval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/geom_interval.Rd
# ['geom_interval.R']
# ['geom_interval', 'geom_interval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/geom_lineribbon.Rd
# ['geom_lineribbon.R']
# ['geom_lineribbon', 'geom_lineribbon']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/geom_pointinterval.Rd
# ['geom_pointinterval.R']
# ['geom_pointinterval', 'geom_pointinterval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/geom_slab.Rd
# ['geom_slab.R']
# ['geom_slab', 'geom_slab']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/geom_slabinterval.Rd
# ['geom_slabinterval.R']
# ['geom_slabinterval', 'geom_slabinterval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/geom_spike.Rd
# ['geom_spike.R']
# ['geom_spike', 'geom_spike']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/geom_swarm.Rd
# ['geom_swarm.R']
# ['geom_swarm', 'geom_swarm']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/geom_weave.Rd
# ['geom_swarm.R']
# ['geom_weave', 'geom_weave']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/ggdist-deprecated.Rd
# ['deprecated.R']
# ['ggdist-deprecated', 'ggdist-deprecated', 'StatSampleSlabinterval', 'stat_sample_slabinterval', 'StatDistSlabinterval', 'stat_dist_slabinterval', 'stat_dist_halfeye', 'stat_dist_eye', 'stat_dist_ccdfinterval', 'stat_dist_cdfinterval', 'stat_dist_gradientinterval', 'stat_dist_slab', 'stat_dist_pointinterval', 'stat_dist_interval', 'stat_dist_lineribbon', 'stat_dist_dotsinterval', 'stat_dist_dots']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/ggdist-ggproto.Rd
# ['abstract_stat_slabinterval.R', 'geom.R']
# ['AbstractStatSlabinterval', 'AbstractStatSlabinterval', 'ggdist-ggproto', 'GeomSlabinterval', 'GeomDotsinterval', 'GeomDots', 'GeomInterval', 'GeomLineribbon', 'GeomPointinterval', 'GeomSlab', 'GeomSpike', 'GeomSwarm', 'GeomWeave', 'PositionDodgejust', 'StatSlabinterval', 'StatPointinterval', 'StatInterval', 'StatSpike']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/ggdist-package.Rd
# ['ggdist-package.R']
# ['ggdist-package', 'ggdist-package', 'ggdist']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/guide_rampbar.Rd
# ['guide_rampbar.R']
# ['guide_rampbar', 'guide_rampbar']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/lkjcorr_marginal.Rd
# ['lkjcorr_marginal.R']
# ['lkjcorr_marginal', 'lkjcorr_marginal', 'dlkjcorr_marginal', 'plkjcorr_marginal', 'qlkjcorr_marginal', 'rlkjcorr_marginal']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/marginalize_lkjcorr.Rd
# ['lkjcorr_marginal.R']
# ['marginalize_lkjcorr', 'marginalize_lkjcorr']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/parse_dist.Rd
# ['parse_dist.R']
# ['parse_dist', 'parse_dist', 'parse_dist.default', 'parse_dist.data.frame', 'parse_dist.character', 'parse_dist.factor', 'parse_dist.brmsprior', 'r_dist_name']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/point_interval.Rd
# ['point_interval.R']
# ['point_interval', 'point_interval', 'point_interval.default', 'point_interval.numeric', 'point_interval.rvar', 'point_interval.distribution', 'qi', 'll', 'ul', 'hdi', 'Mode', 'Mode.default', 'Mode.rvar', 'Mode.distribution', 'hdci', 'mean_qi', 'median_qi', 'mode_qi', 'mean_ll', 'median_ll', 'mode_ll', 'mean_ul', 'median_ul', 'mode_ul', 'mean_hdi', 'median_hdi', 'mode_hdi', 'mean_hdci', 'median_hdci', 'mode_hdci']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/position_dodgejust.Rd
# ['position_dodgejust.R']
# ['position_dodgejust', 'position_dodgejust']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/Pr_.Rd
# ['pr.R']
# ['Pr_', 'Pr_', 'p_']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/RankCorr.Rd
# ['data.R']
# ['RankCorr', 'RankCorr', 'RankCorr_u_tau']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/scales.Rd
# ['scale_.R']
# ['scales', 'scales', 'scale_point_colour_discrete', 'scale_point_color_discrete', 'scale_point_colour_continuous', 'scale_point_color_continuous', 'scale_point_fill_discrete', 'scale_point_fill_continuous', 'scale_point_alpha_continuous', 'scale_point_alpha_discrete', 'scale_point_size_continuous', 'scale_point_size_discrete', 'scale_interval_colour_discrete', 'scale_interval_color_discrete', 'scale_interval_colour_continuous', 'scale_interval_color_continuous', 'scale_interval_alpha_continuous', 'scale_interval_alpha_discrete', 'scale_interval_size_continuous', 'scale_interval_size_discrete', 'scale_interval_linetype_discrete', 'scale_interval_linetype_continuous', 'scale_slab_colour_discrete', 'scale_slab_color_discrete', 'scale_slab_colour_continuous', 'scale_slab_color_continuous', 'scale_slab_fill_discrete', 'scale_slab_fill_continuous', 'scale_slab_alpha_continuous', 'scale_slab_alpha_discrete', 'scale_slab_size_continuous', 'scale_slab_size_discrete', 'scale_slab_linewidth_continuous', 'scale_slab_linewidth_discrete', 'scale_slab_linetype_discrete', 'scale_slab_linetype_continuous', 'scale_slab_shape_discrete', 'scale_slab_shape_continuous', 'guide_colourbar2', 'guide_colorbar2']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/scale_colour_ramp.Rd
# ['scale_colour_ramp.R']
# ['scale_colour_ramp', 'scale_colour_ramp', 'scale_colour_ramp_continuous', 'scale_color_ramp', 'scale_fill_ramp', 'scale_color_ramp_continuous', 'scale_colour_ramp_discrete', 'scale_color_ramp_discrete', 'scale_fill_ramp_continuous', 'scale_fill_ramp_discrete']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/scale_side_mirrored.Rd
# ['scale_side_mirrored.R']
# ['scale_side_mirrored', 'scale_side_mirrored']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/scale_thickness.Rd
# ['scale_thickness.R']
# ['scale_thickness', 'scale_thickness', 'scale_thickness_shared', 'scale_thickness_identity', 'thickness']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/smooth_density.Rd
# ['smooth.R']
# ['smooth_density', 'smooth_density', 'smooth_bounded', 'smooth_unbounded']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/smooth_discrete.Rd
# ['smooth.R']
# ['smooth_discrete', 'smooth_discrete', 'smooth_bar']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/smooth_none.Rd
# ['smooth.R']
# ['smooth_none', 'smooth_none']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_ccdfinterval.Rd
# ['stat_slabinterval.R']
# ['stat_ccdfinterval', 'stat_ccdfinterval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_cdfinterval.Rd
# ['stat_slabinterval.R']
# ['stat_cdfinterval', 'stat_cdfinterval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_dots.Rd
# ['stat_dotsinterval.R']
# ['stat_dots', 'stat_dots']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_dotsinterval.Rd
# ['stat_dotsinterval.R']
# ['stat_dotsinterval', 'stat_dotsinterval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_eye.Rd
# ['stat_slabinterval.R']
# ['stat_eye', 'stat_eye']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_gradientinterval.Rd
# ['stat_slabinterval.R']
# ['stat_gradientinterval', 'stat_gradientinterval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_halfeye.Rd
# ['stat_slabinterval.R']
# ['stat_halfeye', 'stat_halfeye']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_histinterval.Rd
# ['stat_slabinterval.R']
# ['stat_histinterval', 'stat_histinterval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_interval.Rd
# ['stat_interval.R']
# ['stat_interval', 'stat_interval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_lineribbon.Rd
# ['stat_lineribbon.R']
# ['stat_lineribbon', 'stat_lineribbon']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_pointinterval.Rd
# ['stat_pointinterval.R']
# ['stat_pointinterval', 'stat_pointinterval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_ribbon.Rd
# ['stat_lineribbon.R']
# ['stat_ribbon', 'stat_ribbon']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_slab.Rd
# ['stat_slabinterval.R']
# ['stat_slab', 'stat_slab']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_slabinterval.Rd
# ['stat_slabinterval.R']
# ['stat_slabinterval', 'stat_slabinterval']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/stat_spike.Rd
# ['stat_spike.R']
# ['stat_spike', 'stat_spike']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/student_t.Rd
# ['student_t.R']
# ['student_t', 'student_t', 'dstudent_t', 'pstudent_t', 'qstudent_t', 'rstudent_t']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/theme_ggdist.Rd
# ['theme_ggdist.R']
# ['theme_ggdist', 'theme_ggdist', 'theme_tidybayes', 'facet_title_horizontal', 'axis_titles_bottom_left', 'facet_title_left_horizontal', 'facet_title_right_horizontal']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/tidy-format-translators.Rd
# ['tidy_format_translators.R']
# ['tidy-format-translators', 'tidy-format-translators', 'to_broom_names', 'from_broom_names', 'to_ggmcmc_names', 'from_ggmcmc_names']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/weighted_ecdf.Rd
# ['weighted_ecdf.R']
# ['weighted_ecdf', 'weighted_ecdf']
# C:/Users/shawn/Desktop/R/R/mjskay/ggdist/man/weighted_quantile.Rd
# ['weighted_quantile.R']
# ['weighted_quantile', 'weighted_quantile', 'weighted_quantile_fun']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/adam_fit_impl.Rd
# ['parsnip-adam.R']
# ['adam_fit_impl', 'adam_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/adam_params.Rd
# ['dials-adam_params.R']
# ['adam_params', 'adam_params', 'use_constant', 'regressors_treatment', 'outliers_treatment', 'probability_model', 'distribution', 'information_criteria', 'select_order']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/Adam_predict_impl.Rd
# ['parsnip-adam.R']
# ['Adam_predict_impl', 'Adam_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/adam_reg.Rd
# ['parsnip-adam.R']
# ['adam_reg', 'adam_reg']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/add_modeltime_model.Rd
# ['helpers-modeltime_table.R']
# ['add_modeltime_model', 'add_modeltime_model']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/arima_boost.Rd
# ['parsnip-arima_boost.R']
# ['arima_boost', 'arima_boost']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/Arima_fit_impl.Rd
# ['parsnip-arima_reg.R']
# ['Arima_fit_impl', 'Arima_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/arima_params.Rd
# ['dials-arima_params.R']
# ['arima_params', 'arima_params', 'non_seasonal_ar', 'non_seasonal_differences', 'non_seasonal_ma', 'seasonal_ar', 'seasonal_differences', 'seasonal_ma']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/Arima_predict_impl.Rd
# ['parsnip-arima_reg.R']
# ['Arima_predict_impl', 'Arima_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/arima_reg.Rd
# ['parsnip-arima_reg.R']
# ['arima_reg', 'arima_reg']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/arima_xgboost_fit_impl.Rd
# ['parsnip-arima_boost.R']
# ['arima_xgboost_fit_impl', 'arima_xgboost_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/arima_xgboost_predict_impl.Rd
# ['parsnip-arima_boost.R']
# ['arima_xgboost_predict_impl', 'arima_xgboost_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/auto_adam_fit_impl.Rd
# ['parsnip-adam.R']
# ['auto_adam_fit_impl', 'auto_adam_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/Auto_adam_predict_impl.Rd
# ['parsnip-adam.R']
# ['Auto_adam_predict_impl', 'Auto_adam_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/auto_arima_fit_impl.Rd
# ['parsnip-arima_reg.R']
# ['auto_arima_fit_impl', 'auto_arima_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/auto_arima_xgboost_fit_impl.Rd
# ['parsnip-arima_boost.R']
# ['auto_arima_xgboost_fit_impl', 'auto_arima_xgboost_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/combine_modeltime_tables.Rd
# ['helpers-modeltime_table.R']
# ['combine_modeltime_tables', 'combine_modeltime_tables']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/control_modeltime.Rd
# ['utils-control-par.R']
# ['control_modeltime', 'control_modeltime', 'control_refit', 'control_fit_workflowset', 'control_nested_fit', 'control_nested_refit', 'control_nested_forecast']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/create_model_grid.Rd
# ['modeltime-fit-workflowset.R']
# ['create_model_grid', 'create_model_grid']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/create_xreg_recipe.Rd
# ['dev-xregs.R']
# ['create_xreg_recipe', 'create_xreg_recipe']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/croston_fit_impl.Rd
# ['parsnip-exp_smoothing.R']
# ['croston_fit_impl', 'croston_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/croston_predict_impl.Rd
# ['parsnip-exp_smoothing.R']
# ['croston_predict_impl', 'croston_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/dot_prepare_transform.Rd
# ['modeltime-recursive.R']
# ['.prepare_transform', '.prepare_transform', '.prepare_panel_transform']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/drop_modeltime_model.Rd
# ['helpers-modeltime_table.R']
# ['drop_modeltime_model', 'drop_modeltime_model']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/ets_fit_impl.Rd
# ['parsnip-exp_smoothing.R']
# ['ets_fit_impl', 'ets_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/ets_predict_impl.Rd
# ['parsnip-exp_smoothing.R']
# ['ets_predict_impl', 'ets_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/exp_smoothing.Rd
# ['parsnip-exp_smoothing.R']
# ['exp_smoothing', 'exp_smoothing']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/exp_smoothing_params.Rd
# ['dials-ets_params.R']
# ['exp_smoothing_params', 'exp_smoothing_params', 'error', 'trend', 'trend_smooth', 'season', 'damping', 'damping_smooth', 'smooth_level', 'smooth_trend', 'smooth_seasonal']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/get_arima_description.Rd
# ['dev-model_descriptions.R']
# ['get_arima_description', 'get_arima_description']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/get_model_description.Rd
# ['dev-model_descriptions.R']
# ['get_model_description', 'get_model_description']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/get_tbats_description.Rd
# ['dev-model_descriptions.R']
# ['get_tbats_description', 'get_tbats_description']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/is_calibrated.Rd
# ['utils-is_modeltime.R']
# ['is_calibrated', 'is_calibrated']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/is_modeltime_model.Rd
# ['utils-is_modeltime.R']
# ['is_modeltime_model', 'is_modeltime_model']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/is_modeltime_table.Rd
# ['utils-is_modeltime.R']
# ['is_modeltime_table', 'is_modeltime_table']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/is_residuals.Rd
# ['utils-is_modeltime.R']
# ['is_residuals', 'is_residuals']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/load_namespace.Rd
# ['utils-control-par.R']
# ['load_namespace', 'load_namespace']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/log_extractors.Rd
# ['nested-modeltime_extractors.R']
# ['log_extractors', 'log_extractors', 'extract_nested_test_accuracy', 'extract_nested_test_forecast', 'extract_nested_error_report', 'extract_nested_best_model_report', 'extract_nested_future_forecast', 'extract_nested_modeltime_table', 'extract_nested_train_split', 'extract_nested_test_split']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/m750.Rd
# ['data.R']
# ['m750', 'm750']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/m750_models.Rd
# ['data.R']
# ['m750_models', 'm750_models']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/m750_splits.Rd
# ['data.R']
# ['m750_splits', 'm750_splits']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/m750_training_resamples.Rd
# ['data.R']
# ['m750_training_resamples', 'm750_training_resamples']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/maape.Rd
# ['yardstick-metric-sets.R']
# ['maape', 'maape']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/maape_vec.Rd
# ['yardstick-metric-sets.R']
# ['maape_vec', 'maape_vec']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/make_ts_splits.Rd
# ['nested-modeltime_data_prep.R']
# ['make_ts_splits', 'make_ts_splits']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/mdl_time_forecast.Rd
# ['modeltime-forecast.R']
# ['mdl_time_forecast', 'mdl_time_forecast']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/mdl_time_refit.Rd
# ['modeltime-refit.R']
# ['mdl_time_refit', 'mdl_time_refit']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/metric_sets.Rd
# ['yardstick-metric-sets.R']
# ['metric_sets', 'metric_sets', 'default_forecast_accuracy_metric_set', 'extended_forecast_accuracy_metric_set']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_accuracy.Rd
# ['modeltime-accuracy.R']
# ['modeltime_accuracy', 'modeltime_accuracy']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_calibrate.Rd
# ['modeltime-calibrate.R']
# ['modeltime_calibrate', 'modeltime_calibrate']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_fit_workflowset.Rd
# ['modeltime-fit-workflowset.R']
# ['modeltime_fit_workflowset', 'modeltime_fit_workflowset']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_forecast.Rd
# ['modeltime-forecast.R']
# ['modeltime_forecast', 'modeltime_forecast']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_nested_fit.Rd
# ['nested-modeltime_fit.R']
# ['modeltime_nested_fit', 'modeltime_nested_fit']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_nested_forecast.Rd
# ['nested-modeltime-forecast.R']
# ['modeltime_nested_forecast', 'modeltime_nested_forecast']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_nested_refit.Rd
# ['nested-modeltime_refit.R']
# ['modeltime_nested_refit', 'modeltime_nested_refit']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_nested_select_best.Rd
# ['nested-modeltime_select_best.R']
# ['modeltime_nested_select_best', 'modeltime_nested_select_best']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_refit.Rd
# ['modeltime-refit.R']
# ['modeltime_refit', 'modeltime_refit']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_residuals.Rd
# ['modeltime-residuals.R']
# ['modeltime_residuals', 'modeltime_residuals']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_residuals_test.Rd
# ['modeltime-residuals-tests.R']
# ['modeltime_residuals_test', 'modeltime_residuals_test']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/modeltime_table.Rd
# ['modeltime-table.R']
# ['modeltime_table', 'modeltime_table', 'as_modeltime_table']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/naive_fit_impl.Rd
# ['parsnip-naive_reg.R']
# ['naive_fit_impl', 'naive_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/naive_predict_impl.Rd
# ['parsnip-naive_reg.R']
# ['naive_predict_impl', 'naive_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/naive_reg.Rd
# ['parsnip-naive_reg.R']
# ['naive_reg', 'naive_reg']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/new_modeltime_bridge.Rd
# ['dev-constructor.R']
# ['new_modeltime_bridge', 'new_modeltime_bridge']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/nnetar_fit_impl.Rd
# ['parsnip-nnetar_reg.R']
# ['nnetar_fit_impl', 'nnetar_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/nnetar_params.Rd
# ['dials-nnetar_params.R']
# ['nnetar_params', 'nnetar_params', 'num_networks']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/nnetar_predict_impl.Rd
# ['parsnip-nnetar_reg.R']
# ['nnetar_predict_impl', 'nnetar_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/nnetar_reg.Rd
# ['parsnip-nnetar_reg.R']
# ['nnetar_reg', 'nnetar_reg']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/panel_tail.Rd
# ['modeltime-recursive.R']
# ['panel_tail', 'panel_tail']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/parallel_start.Rd
# ['utils-control-par.R']
# ['parallel_start', 'parallel_start', 'parallel_stop']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/parse_index.Rd
# ['dev-parse_index.R']
# ['parse_index', 'parse_index', 'parse_index_from_data', 'parse_period_from_index']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/pipe.Rd
# ['utils-pipe.R']
# ['\\%>\\%', '\\%>\\%']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/plot_modeltime_forecast.Rd
# ['modeltime-forecast-plot.R']
# ['plot_modeltime_forecast', 'plot_modeltime_forecast']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/plot_modeltime_residuals.Rd
# ['modeltime-residuals-plot.R']
# ['plot_modeltime_residuals', 'plot_modeltime_residuals']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/pluck_modeltime_model.Rd
# ['helpers-modeltime_table.R']
# ['pluck_modeltime_model', 'pluck_modeltime_model', 'pluck_modeltime_model.mdl_time_tbl', 'pull_modeltime_model']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/prep_nested.Rd
# ['nested-modeltime_data_prep.R']
# ['prep_nested', 'prep_nested', 'extend_timeseries', 'nest_timeseries', 'split_nested_timeseries']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/prophet_boost.Rd
# ['parsnip-prophet_boost.R']
# ['prophet_boost', 'prophet_boost']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/prophet_fit_impl.Rd
# ['parsnip-prophet_reg.R']
# ['prophet_fit_impl', 'prophet_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/prophet_params.Rd
# ['dials-prophet_params.R']
# ['prophet_params', 'prophet_params', 'growth', 'changepoint_num', 'changepoint_range', 'seasonality_yearly', 'seasonality_weekly', 'seasonality_daily', 'prior_scale_changepoints', 'prior_scale_seasonality', 'prior_scale_holidays']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/prophet_predict_impl.Rd
# ['parsnip-prophet_reg.R']
# ['prophet_predict_impl', 'prophet_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/prophet_reg.Rd
# ['parsnip-prophet_reg.R']
# ['prophet_reg', 'prophet_reg']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/prophet_xgboost_fit_impl.Rd
# ['parsnip-prophet_boost.R']
# ['prophet_xgboost_fit_impl', 'prophet_xgboost_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/prophet_xgboost_predict_impl.Rd
# ['parsnip-prophet_boost.R']
# ['prophet_xgboost_predict_impl', 'prophet_xgboost_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/pull_modeltime_residuals.Rd
# ['helpers-modeltime_residuals.R']
# ['pull_modeltime_residuals', 'pull_modeltime_residuals']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/pull_parsnip_preprocessor.Rd
# ['utils-parsnip-helpers.R']
# ['pull_parsnip_preprocessor', 'pull_parsnip_preprocessor']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/recipe_helpers.Rd
# ['dev-xregs.R']
# ['recipe_helpers', 'recipe_helpers', 'juice_xreg_recipe', 'bake_xreg_recipe']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/recursive.Rd
# ['modeltime-recursive.R']
# ['recursive', 'recursive']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/seasonal_reg.Rd
# ['parsnip-seasonal_reg.R']
# ['seasonal_reg', 'seasonal_reg']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/smooth_fit_impl.Rd
# ['parsnip-exp_smoothing.R']
# ['smooth_fit_impl', 'smooth_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/smooth_predict_impl.Rd
# ['parsnip-exp_smoothing.R']
# ['smooth_predict_impl', 'smooth_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/snaive_fit_impl.Rd
# ['parsnip-naive_reg.R']
# ['snaive_fit_impl', 'snaive_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/snaive_predict_impl.Rd
# ['parsnip-naive_reg.R']
# ['snaive_predict_impl', 'snaive_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/stlm_arima_fit_impl.Rd
# ['parsnip-seasonal_reg.R']
# ['stlm_arima_fit_impl', 'stlm_arima_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/stlm_arima_predict_impl.Rd
# ['parsnip-seasonal_reg.R']
# ['stlm_arima_predict_impl', 'stlm_arima_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/stlm_ets_fit_impl.Rd
# ['parsnip-seasonal_reg.R']
# ['stlm_ets_fit_impl', 'stlm_ets_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/stlm_ets_predict_impl.Rd
# ['parsnip-seasonal_reg.R']
# ['stlm_ets_predict_impl', 'stlm_ets_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/summarize_accuracy_metrics.Rd
# ['yardstick-metric-sets.R']
# ['summarize_accuracy_metrics', 'summarize_accuracy_metrics']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/table_modeltime_accuracy.Rd
# ['modeltime-accuracy-table.R']
# ['table_modeltime_accuracy', 'table_modeltime_accuracy']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/tbats_fit_impl.Rd
# ['parsnip-seasonal_reg.R']
# ['tbats_fit_impl', 'tbats_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/tbats_predict_impl.Rd
# ['parsnip-seasonal_reg.R']
# ['tbats_predict_impl', 'tbats_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/temporal_hierarchy.Rd
# ['parsnip-temporal_hierarchy.R']
# ['temporal_hierarchy', 'temporal_hierarchy']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/temporal_hierarchy_params.Rd
# ['dials-temporal_hierarchy_params.R']
# ['temporal_hierarchy_params', 'temporal_hierarchy_params', 'combination_method', 'use_model']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/temporal_hier_fit_impl.Rd
# ['parsnip-temporal_hierarchy.R']
# ['temporal_hier_fit_impl', 'temporal_hier_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/temporal_hier_predict_impl.Rd
# ['parsnip-temporal_hierarchy.R']
# ['temporal_hier_predict_impl', 'temporal_hier_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/theta_fit_impl.Rd
# ['parsnip-exp_smoothing.R']
# ['theta_fit_impl', 'theta_fit_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/theta_predict_impl.Rd
# ['parsnip-exp_smoothing.R']
# ['theta_predict_impl', 'theta_predict_impl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/tidyeval.Rd
# ['utils-tidy-eval.R']
# ['tidyeval', 'tidyeval', 'expr', 'enquo', 'enquos', 'sym', 'syms', '.data', ':=', 'as_name', 'as_label']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/time_series_params.Rd
# ['dials-ts_params.R']
# ['time_series_params', 'time_series_params', 'seasonal_period']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/type_sum.mdl_time_tbl.Rd
# ['tibble-type_sum.R']
# ['type_sum.mdl_time_tbl', 'type_sum.mdl_time_tbl']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/update_modeltime_model.Rd
# ['helpers-modeltime_table.R']
# ['update_modeltime_model', 'update_modeltime_model']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/update_model_description.Rd
# ['helpers-modeltime_table.R']
# ['update_model_description', 'update_model_description', 'update_modeltime_description']
# C:/Users/shawn/Desktop/R/R/business-science/modeltime/man/window_function_fit_impl.Rd
# ['parsnip-window_reg.R']
# ['window_function_fit_impl', 'window_function_fit_impl']
# ...
# ['copy_lookup_para_file.R']
# ['copy_lookup_para_file', 'copy_lookup_para_file']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/copy_xlsx_files.Rd
# ['copy_xlsx_files.R']
# ['copy_xlsx_files', 'copy_xlsx_files']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/create_emshoff91_import.Rd
# ['emshoff91.R']
# ['create_emshoff91_import', 'create_emshoff91_import']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/create_sftp_connection.Rd
# ['measurement-chains.R']
# ['create_sftp_connection', 'create_sftp_connection']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/delete_registry.Rd
# ['convert_xls_as_xlsx.R']
# ['delete_registry', 'delete_registry']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/download_measurementchains_data.Rd
# ['measurement-chains.R']
# ['download_measurementchains_data', 'download_measurementchains_data']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/emshoff91_list_to_df.Rd
# ['emshoff91_remap_values.R']
# ['emshoff91_list_to_df', 'emshoff91_list_to_df']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/emshoff91_remap_values.Rd
# ['emshoff91_remap_values.R']
# ['emshoff91_remap_values', 'emshoff91_remap_values']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/gather_and_join_1.Rd
# ['read_bwb_data.R']
# ['gather_and_join_1', 'gather_and_join_1']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/gather_and_join_2.Rd
# ['read_bwb_data.R']
# ['gather_and_join_2', 'gather_and_join_2']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_excelcnv_exe.Rd
# ['convert_xls_as_xlsx.R']
# ['get_excelcnv_exe', 'get_excelcnv_exe']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_foerdermengen.Rd
# ['get_foerdermengen.R']
# ['get_foerdermengen', 'get_foerdermengen']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_foerdermengen_gal_fri.Rd
# ['get_foerdermengen_gal_fri.R']
# ['get_foerdermengen_gal_fri', 'get_foerdermengen_gal_fri']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_measurementchains_files.Rd
# ['measurement-chains.R']
# ['get_measurementchains_files', 'get_measurementchains_files']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_measurementchains_metadata.Rd
# ['measurement-chains.R']
# ['get_measurementchains_metadata', 'get_measurementchains_metadata']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_measurement_chain_data_on_cloud.Rd
# ['get_measurement_chain_data_on_cloud.R']
# ['get_measurement_chain_data_on_cloud', 'get_measurement_chain_data_on_cloud']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_measurmentchains_data_stats.Rd
# ['get_measurmentchains_data_stats.R']
# ['get_measurmentchains_data_stats', 'get_measurmentchains_data_stats']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_meta_sheet_or_stop.Rd
# ['helpers.R']
# ['get_meta_sheet_or_stop', 'get_meta_sheet_or_stop']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_pandoc_info.Rd
# ['get_pandoc_info.R']
# ['get_pandoc_info', 'get_pandoc_info']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_parameters_meta.Rd
# ['add_lookup_data.R']
# ['get_parameters_meta', 'get_parameters_meta']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_phreeqc_data.Rd
# ['prepare_phreeqc_input.R']
# ['get_phreeqc_data', 'get_phreeqc_data']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/get_site_id.Rd
# ['helpers.R']
# ['get_site_id', 'get_site_id']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/import_labor.Rd
# ['read_bwb_data.R']
# ['import_labor', 'import_labor']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/order_measurement_chain_data.Rd
# ['measurement-chains.R']
# ['order_measurement_chain_data', 'order_measurement_chain_data']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/pipe.Rd
# ['utils-pipe.R']
# ['\\%>\\%', '\\%>\\%']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/plot_measurementchains.Rd
# ['plot_measurementchains.R']
# ['plot_measurementchains', 'plot_measurementchains']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/prepare_phreeqc_input.Rd
# ['prepare_phreeqc_input.R']
# ['prepare_phreeqc_input', 'prepare_phreeqc_input']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/print_datatype_info_if.Rd
# ['helpers.R']
# ['print_datatype_info_if', 'print_datatype_info_if']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/read_bwb_data.Rd
# ['read_bwb_data.R']
# ['read_bwb_data', 'read_bwb_data']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/read_bwb_header1_meta.Rd
# ['read_bwb_data.R']
# ['read_bwb_header1_meta', 'read_bwb_header1_meta']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/read_bwb_header2.Rd
# ['read_bwb_data.R']
# ['read_bwb_header2', 'read_bwb_header2']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/read_bwb_header4.Rd
# ['read_bwb_data.R']
# ['read_bwb_header4', 'read_bwb_header4']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/read_emshoff91_ods.Rd
# ['emshoff91.R']
# ['read_emshoff91_ods', 'read_emshoff91_ods']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/read_isotopes.Rd
# ['read_isotopes.R']
# ['read_isotopes', 'read_isotopes']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/read_lab_bwb.Rd
# ['read_lab_bwb.R']
# ['read_lab_bwb', 'read_lab_bwb']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/read_master_data.Rd
# ['read_lab_bwb.R']
# ['read_master_data', 'read_master_data']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/read_measurementchains_data.Rd
# ['measurement-chains.R']
# ['read_measurementchains_data', 'read_measurementchains_data']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/read_multiple_emshoff91_ods.Rd
# ['emshoff91.R']
# ['read_multiple_emshoff91_ods', 'read_multiple_emshoff91_ods']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/replace_nanb_with_na.Rd
# ['read_lab_bwb.R']
# ['replace_nanb_with_na', 'replace_nanb_with_na']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/safe_office_folder.Rd
# ['convert_xls_as_xlsx.R']
# ['safe_office_folder', 'safe_office_folder']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/stop_if_duplicated_samples_found.Rd
# ['stop_if_duplicated_samples_found.R']
# ['stop_if_duplicated_samples_found', 'stop_if_duplicated_samples_found']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/stop_on_missing_or_inform_on_extra_sheets.Rd
# ['helpers.R']
# ['stop_on_missing_or_inform_on_extra_sheets', 'stop_on_missing_or_inform_on_extra_sheets']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/to_full_metadata_2.Rd
# ['read_bwb_data.R']
# ['to_full_metadata_2', 'to_full_metadata_2']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/to_full_metadata_4.Rd
# ['read_bwb_data.R']
# ['to_full_metadata_4', 'to_full_metadata_4']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.geosalz/man/write_measurementchains_data.Rd
# ['write_measurementchains_data.R']
# ['write_measurementchains_data', 'write_measurementchains_data']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/analyse.Rd
# ['analyse.R']
# ['analyse', 'analyse']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/arg_names.Rd
# ['utils.R']
# ['arg_names', 'arg_names']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/extract_from_parse_tree.Rd
# ['extract_from_parse_tree.R']
# ['extract_from_parse_tree', 'extract_from_parse_tree']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/get_elements_by_type.Rd
# ['get_elements_by_type.R']
# ['get_elements_by_type', 'get_elements_by_type']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/get_full_function_info.Rd
# ['main.R']
# ['get_full_function_info', 'get_full_function_info']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/get_function_call_frequency.Rd
# ['get_package_function_usage.R']
# ['get_function_call_frequency', 'get_function_call_frequency']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/get_names_of_used_packages.Rd
# ['get_names_of_used_packages.R']
# ['get_names_of_used_packages', 'get_names_of_used_packages']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/get_package_function_usage.Rd
# ['get_package_function_usage.R']
# ['get_package_function_usage', 'get_package_function_usage']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/get_package_usage_per_script.Rd
# ['get_package_usage_per_script.R']
# ['get_package_usage_per_script', 'get_package_usage_per_script']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/get_string_constants_in_scripts.Rd
# ['get_string_constants_in_scripts.R']
# ['get_string_constants_in_scripts', 'get_string_constants_in_scripts']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/parse_scripts.Rd
# ['main.R']
# ['parse_scripts', 'parse_scripts']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/to_full_script_info.Rd
# ['stat.R']
# ['to_full_script_info', 'to_full_script_info']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.code/man/walk_tree.Rd
# ['walk_tree.R']
# ['walk_tree', 'walk_tree']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/dictionary_size.Rd
# ['helpers.R']
# ['dictionary_size', 'dictionary_size']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/get_dictionary_one_by_one.Rd
# ['get_dictionary_one_by_one.R']
# ['get_dictionary_one_by_one', 'get_dictionary_one_by_one']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/named_vector_to_data_frame.Rd
# ['utils.R']
# ['named_vector_to_data_frame', 'named_vector_to_data_frame']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/order_decreasingly_by.Rd
# ['utils.R']
# ['order_decreasingly_by', 'order_decreasingly_by']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/print_compressed.Rd
# ['helpers.R']
# ['print_compressed', 'print_compressed']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/print_dict.Rd
# ['helpers.R']
# ['print_dict', 'print_dict']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/random_paths.Rd
# ['random_paths.R']
# ['random_paths', 'random_paths']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/rescore_and_reorder_frequency_data.Rd
# ['get_dictionary_one_by_one.R']
# ['rescore_and_reorder_frequency_data', 'rescore_and_reorder_frequency_data']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/sorted_importance.Rd
# ['sorted_importance.R']
# ['sorted_importance', 'sorted_importance']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/starts_with_parts.Rd
# ['utils_path.R']
# ['starts_with_parts', 'starts_with_parts']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/to_cumulative_id.Rd
# ['to_cumulative_id.R']
# ['to_cumulative_id', 'to_cumulative_id']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/to_dictionary.Rd
# ['compress_paths.R']
# ['to_dictionary', 'to_dictionary']
# C:/Users/shawn/Desktop/R/R/KWB-R/kwb.pathdict/man/use_dictionary.Rd
# ['use_dictionary.R']
# ['use_dictionary', 'use_dictionary']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/pgmcs/man/demo_population_simulation.Rd
# ['demo-population-simulation.R']
# ['demo_population_simulation', 'demo_population_simulation']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/pgmcs/man/population_simulation.Rd
# ['population-simulation.R']
# ['population_simulation', 'population_simulation']
# C:/Users/shawn/Desktop/R/R/SciViews/svSweave/man/clean_lyx.Rd
# ['clean_lyx.R', 'tangle_lyx.R', 'weave_lyx.R']
# ['clean_lyx', 'clean_lyx', 'cleanLyxRnw', 'tangle_lyx', 'tangleLyxRnw', 'purl_lyx', 'purlLyxRnw', 'weave_lyx', 'weaveLyxRnw', 'knit_lyx', 'knitLyxRnw']
# C:/Users/shawn/Desktop/R/R/SciViews/svSweave/man/fig_id.Rd
# ['new_labelling.R']
# ['fig_id', 'fig_id', 'fig_id_auto']
# C:/Users/shawn/Desktop/R/R/SciViews/svSweave/man/new_labelling.Rd
# ['new_labelling.R']
# ['new_labelling', 'new_labelling', 'newLabelling', 'fig', 'tab', 'eq']
# C:/Users/shawn/Desktop/R/R/SciViews/svSweave/man/subsettable.Rd
# ['new_labelling.R']
# ['subsettable', 'subsettable', '$.subsettable_labelling_ref']
# C:/Users/shawn/Desktop/R/R/SciViews/svSweave/man/svSweave-package.Rd
# ['svSweave-package.R']
# ['svSweave-package', 'svSweave', 'svSweave-package']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/arma_acf.Rd
# ['arma_acf.R']
# ['arma_acf', 'arma_acf']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/cochran_mq.Rd
# ['cochran_mq.R']
# ['cochran_mq', 'cochran_mq']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/crouse_msd.Rd
# ['crouse_msd.R']
# ['crouse_msd', 'crouse_msd']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/csi_model.Rd
# ['csi_model.R']
# ['csi_model', 'csi_model']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/csi_resid.Rd
# ['csi_resid.R']
# ['csi_resid', 'csi_resid']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/csi_sim.Rd
# ['csi_sim.R']
# ['csi_sim', 'csi_sim']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/downsample.Rd
# ['downsample.R']
# ['downsample', 'downsample']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/drift_functions.Rd
# ['drift_functions.R']
# ['drift_functions', 'drift_functions', 'drift_linear', 'drift_none', 'drift_quadratic']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/farma_acf.Rd
# ['farma_acf.R']
# ['farma_acf', 'farma_acf']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/farma_fit.Rd
# ['farma_fit.R']
# ['farma_fit', 'farma_fit']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/farma_model.Rd
# ['farma_model.R']
# ['farma_model', 'farma_model']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/fbm_acf.Rd
# ['fbm_acf.R']
# ['fbm_acf', 'fbm_acf']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/fbm_fit.Rd
# ['fbm_fit.R']
# ['fbm_fit', 'fbm_fit']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/fbm_model.Rd
# ['fbm_model.R']
# ['fbm_model', 'fbm_model']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/fbm_msd.Rd
# ['fbm_msd.R']
# ['fbm_msd', 'fbm_msd']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/fsd_acf.Rd
# ['fsd_acf.R']
# ['fsd_acf', 'fsd_acf']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/fsd_fit.Rd
# ['fsd_fit.R']
# ['fsd_fit', 'fsd_fit']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/fsd_model.Rd
# ['fsd_model.R']
# ['fsd_model', 'fsd_model']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/fsd_msd.Rd
# ['fsd_msd.R']
# ['fsd_msd', 'fsd_msd']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/hbe.Rd
# ['hbe.R']
# ['hbe', 'hbe']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/logit.Rd
# ['logit.R']
# ['logit', 'logit', 'ilogit']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/ls_fit.Rd
# ['ls_fit.R']
# ['ls_fit', 'ls_fit', 'ls_msd_fit']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/ma_acf.Rd
# ['arma_acf.R']
# ['ma_acf', 'ma_acf']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/msd_fit.Rd
# ['msd_fit.R']
# ['msd_fit', 'msd_fit']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/msd_subdiff.Rd
# ['msd_subdiff.R']
# ['msd_subdiff', 'msd_subdiff']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/norm_pval.Rd
# ['norm_pval.R']
# ['norm_pval', 'norm_pval', 'ad_pval', 'sw_pval', 'bc_pval']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/prony_acf.Rd
# ['prony_acf.R']
# ['prony_acf', 'prony_acf']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/prony_coeff.Rd
# ['prony_coeff.R']
# ['prony_coeff', 'prony_coeff']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/prony_msd.Rd
# ['prony_msd.R']
# ['prony_msd', 'prony_msd']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/rouse_acf.Rd
# ['rouse_acf.R']
# ['rouse_acf', 'rouse_acf']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/rouse_msd.Rd
# ['rouse_msd.R']
# ['rouse_msd', 'rouse_msd']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/rouse_sub.Rd
# ['rouse_sub.R']
# ['rouse_sub', 'rouse_sub']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/subdiff-package.Rd
# ['subdiff-package.R']
# ['subdiff-package', 'subdiff', 'subdiff-package']
# C:/Users/shawn/Desktop/R/R/mlysy/subdiff/man/trans_Sigma.Rd
# ['trans_Sigma.R']
# ['trans_Sigma', 'trans_Sigma', 'itrans_Sigma']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/bisecpp/man/assess.Rd
# ['bisec-fit.R']
# ['assess', 'assess']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/bisecpp/man/base.Rd
# ['bisec-optim.R']
# ['base', 'base']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/bisecpp/man/biosec_optim_impl.Rd
# ['bisec-optim.R']
# ['biosec_optim_impl', 'biosec_optim_impl']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/bisecpp/man/bisec_fit.Rd
# ['bisec-fit.R']
# ['bisec_fit', 'bisec_fit']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/bisecpp/man/bisec_optim.Rd
# ['bisec-optim.R']
# ['bisec_optim', 'bisec_optim']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/bisecpp/man/f_AI2_out.Rd
# ['AI2-case.R']
# ['f_AI2_out', 'f_AI2_out']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/bisecpp/man/f_protein.Rd
# ['AI2-case.R']
# ['f_protein', 'f_protein']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/bisecpp/man/R_square.Rd
# ['bisec-fit.R']
# ['R_square', 'R_square']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/bisecpp/man/simulate_data.Rd
# ['simulate-fit.R']
# ['simulate_data', 'simulate_data']
# C:/Users/shawn/Desktop/R/R/dongzhuoer/bisecpp/man/simulate_partition_fit.Rd
# ['simulate-fit.R']
# ['simulate_partition_fit', 'simulate_partition_fit']

# %%
Rfile = open('tesselle/chronos/subset.R').read()
tokens = get_type(parser, Rfile, r)
pprint.pprint(tokens)
# Out:
# {((0, 0), (0, 8), 'comment'): '# SUBSET',
#  ((1, 0), (1, 25), 'comment'): "#' @include AllGenerics.R",
#  ((2, 0), (2, 4), 'null'): 'NULL',
#  ((2, 4), (4, 0), '\n'): '',
#  ((4, 0), (4, 80), 'comment'): '# Extract '
#                                '======================================================================',
#  ((5, 0), (5, 80), 'comment'): '## [ '
#                                '---------------------------------------------------------------------------',
#  ((6, 0), (6, 10), 'comment'): "#' @export",
#  ((7, 0), (7, 17), 'comment'): "#' @rdname subset",
#  ((8, 0), (8, 28), 'comment'): "#' @aliases [,RataDie-method",
#  ((9, 0), (9, 9), 'identifier'): 'setMethod',
#  ((9, 9), (9, 10), '('): '(',
#  ((10, 2), (10, 3), 'identifier'): 'f',
#  ((10, 4), (10, 5), '='): '=',
#  ((10, 6), (10, 9), 'string'): '"["',
#  ((10, 9), (10, 10), ','): ',',
#  ((11, 2), (11, 11), 'identifier'): 'signature',
#  ((11, 12), (11, 13), '='): '=',
#  ((11, 14), (11, 15), 'identifier'): 'c',
#  ((11, 15), (11, 16), '('): '(',
#  ((11, 16), (11, 17), 'identifier'): 'x',
#  ((11, 18), (11, 19), '='): '=',
#  ((11, 20), (11, 29), 'string'): '"RataDie"',
#  ((11, 29), (11, 30), ')'): ')',
#  ((11, 30), (11, 31), ','): ',',
#  ((12, 2), (12, 10), 'function'): 'function',
#  ((12, 10), (12, 11), '('): '(',
#  ((12, 11), (12, 12), 'identifier'): 'x',
#  ((12, 12), (12, 13), ','): ',',
#  ((12, 14), (12, 15), 'identifier'): 'i',
#  ((12, 15), (12, 16), ')'): ')',
#  ((12, 17), (12, 18), '{'): '{',
#  ((13, 4), (13, 5), 'identifier'): 'z',
#  ((13, 6), (13, 8), '<-'): '<-',
#  ((13, 9), (13, 16), 'identifier'): 'methods',
#  ((13, 16), (13, 18), '::'): '::',
#  ((13, 18), (13, 32), 'identifier'): 'callNextMethod',
#  ((13, 32), (13, 33), '('): '(',
#  ((13, 33), (13, 34), ')'): ')',
#  ((13, 35), (13, 57), 'comment'): '# Method for `numeric`',
#  ((13, 57), (14, 0), '\n'): '',
#  ((14, 4), (14, 11), 'identifier'): 'methods',
#  ((14, 11), (14, 13), '::'): '::',
#  ((14, 13), (14, 23), 'identifier'): 'initialize',
#  ((14, 23), (14, 24), '('): '(',
#  ((14, 24), (14, 25), 'identifier'): 'x',
#  ((14, 25), (14, 26), ','): ',',
#  ((14, 27), (14, 28), 'identifier'): 'z',
#  ((14, 28), (14, 29), ')'): ')',
#  ((14, 29), (15, 0), '\n'): '',
#  ((15, 2), (15, 3), '}'): '}',
#  ((16, 0), (16, 1), ')'): ')',
#  ((16, 1), (18, 0), '\n'): '',
#  ((18, 0), (18, 10), 'comment'): "#' @export",
#  ((19, 0), (19, 17), 'comment'): "#' @rdname subset",
#  ((20, 0), (20, 31), 'comment'): "#' @aliases [,TimeSeries-method",
#  ((21, 0), (21, 9), 'identifier'): 'setMethod',
#  ((21, 9), (21, 10), '('): '(',
#  ((22, 2), (22, 3), 'identifier'): 'f',
#  ((22, 4), (22, 5), '='): '=',
#  ((22, 6), (22, 9), 'string'): '"["',
#  ((22, 9), (22, 10), ','): ',',
#  ((23, 2), (23, 11), 'identifier'): 'signature',
#  ((23, 12), (23, 13), '='): '=',
#  ((23, 14), (23, 15), 'identifier'): 'c',
#  ((23, 15), (23, 16), '('): '(',
#  ((23, 16), (23, 17), 'identifier'): 'x',
#  ((23, 18), (23, 19), '='): '=',
#  ((23, 20), (23, 32), 'string'): '"TimeSeries"',
#  ((23, 32), (23, 33), ')'): ')',
#  ((23, 33), (23, 34), ','): ',',
#  ((24, 2), (24, 10), 'function'): 'function',
#  ((24, 10), (24, 11), '('): '(',
#  ((24, 11), (24, 12), 'identifier'): 'x',
#  ((24, 12), (24, 13), ','): ',',
#  ((24, 14), (24, 15), 'identifier'): 'i',
#  ((24, 15), (24, 16), ','): ',',
#  ((24, 17), (24, 18), 'identifier'): 'j',
#  ((24, 18), (24, 19), ','): ',',
#  ((24, 20), (24, 23), 'dots'): '...',
#  ((24, 23), (24, 24), ','): ',',
#  ((24, 25), (24, 29), 'identifier'): 'drop',
#  ((24, 30), (24, 31), '='): '=',
#  ((24, 32), (24, 37), 'false'): 'FALSE',
#  ((24, 37), (24, 38), ')'): ')',
#  ((24, 39), (24, 40), '{'): '{',
#  ((25, 4), (25, 5), 'identifier'): 'z',
#  ((25, 6), (25, 8), '<-'): '<-',
#  ((25, 9), (25, 16), 'identifier'): 'methods',
#  ((25, 16), (25, 18), '::'): '::',
#  ((25, 18), (25, 32), 'identifier'): 'callNextMethod',
#  ((25, 32), (25, 33), '('): '(',
#  ((25, 33), (25, 34), ')'): ')',
#  ((25, 35), (25, 56), 'comment'): '# Method for `matrix`',
#  ((25, 56), (27, 0), '\n'): '',
#  ((27, 4), (27, 6), 'if'): 'if',
#  ((27, 7), (27, 8), '('): '(',
#  ((27, 8), (27, 15), 'identifier'): 'is.null',
#  ((27, 15), (27, 16), '('): '(',
#  ((27, 16), (27, 19), 'identifier'): 'dim',
#  ((27, 19), (27, 20), '('): '(',
#  ((27, 20), (27, 21), 'identifier'): 'z',
#  ((27, 21), (27, 22), ')'): ')',
#  ((27, 22), (27, 23), ')'): ')',
#  ((27, 24), (27, 26), '||'): '||',
#  ((27, 27), (27, 33), 'identifier'): 'isTRUE',
#  ((27, 33), (27, 34), '('): '(',
#  ((27, 34), (27, 38), 'identifier'): 'drop',
#  ((27, 38), (27, 39), ')'): ')',
#  ((27, 39), (27, 40), ')'): ')',
#  ((27, 41), (27, 47), 'identifier'): 'return',
#  ((27, 47), (27, 48), '('): '(',
#  ((27, 48), (27, 49), 'identifier'): 'z',
#  ((27, 49), (27, 50), ')'): ')',
#  ((27, 50), (29, 0), '\n'): '',
#  ((29, 4), (29, 8), 'identifier'): 'time',
#  ((29, 9), (29, 11), '<-'): '<-',
#  ((29, 12), (29, 13), 'identifier'): 'x',
#  ((29, 13), (29, 14), '@'): '@',
#  ((29, 14), (29, 18), 'identifier'): 'time',
#  ((29, 18), (30, 0), '\n'): '',
#  ((30, 4), (30, 6), 'if'): 'if',
#  ((30, 7), (30, 8), '('): '(',
#  ((30, 8), (30, 9), '!'): '!',
#  ((30, 9), (30, 16), 'identifier'): 'missing',
#  ((30, 16), (30, 17), '('): '(',
#  ((30, 17), (30, 18), 'identifier'): 'i',
#  ((30, 18), (30, 19), ')'): ')',
#  ((30, 19), (30, 20), ')'): ')',
#  ((30, 21), (30, 22), '{'): '{',
#  ((31, 6), (31, 10), 'identifier'): 'time',
#  ((31, 11), (31, 13), '<-'): '<-',
#  ((31, 14), (31, 18), 'identifier'): 'time',
#  ((31, 18), (31, 19), '['): '[',
#  ((31, 19), (31, 20), 'identifier'): 'i',
#  ((31, 20), (31, 21), ']'): ']',
#  ((31, 21), (32, 0), '\n'): '',
#  ((32, 4), (32, 5), '}'): '}',
#  ((32, 5), (33, 0), '\n'): '',
#  ((33, 4), (33, 11), 'identifier'): 'methods',
#  ((33, 11), (33, 13), '::'): '::',
#  ((33, 13), (33, 23), 'identifier'): 'initialize',
#  ((33, 23), (33, 24), '('): '(',
#  ((33, 24), (33, 25), 'identifier'): 'x',
#  ((33, 25), (33, 26), ','): ',',
#  ((33, 27), (33, 28), 'identifier'): 'z',
#  ((33, 28), (33, 29), ','): ',',
#  ((33, 30), (33, 34), 'identifier'): 'time',
#  ((33, 35), (33, 36), '='): '=',
#  ((33, 37), (33, 41), 'identifier'): 'time',
#  ((33, 41), (33, 42), ')'): ')',
#  ((33, 42), (34, 0), '\n'): '',
#  ((34, 2), (34, 3), '}'): '}',
#  ((35, 0), (35, 1), ')'): ')',
#  ((35, 1), (37, 0), '\n'): '',
#  ((37, 0), (37, 80), 'comment'): '# Window '
#                                  '=======================================================================',
#  ((38, 0), (38, 10), 'comment'): "#' @export",
#  ((39, 0), (39, 17), 'comment'): "#' @rdname window",
#  ((40, 0), (40, 36), 'comment'): "#' @aliases window,TimeSeries-method",
#  ((41, 0), (41, 9), 'identifier'): 'setMethod',
#  ((41, 9), (41, 10), '('): '(',
#  ((42, 2), (42, 3), 'identifier'): 'f',
#  ((42, 4), (42, 5), '='): '=',
#  ((42, 6), (42, 14), 'string'): '"window"',
#  ((42, 14), (42, 15), ','): ',',
#  ((43, 2), (43, 11), 'identifier'): 'signature',
#  ((43, 12), (43, 13), '='): '=',
#  ((43, 14), (43, 26), 'string'): '"TimeSeries"',
#  ((43, 26), (43, 27), ','): ',',
#  ((44, 2), (44, 12), 'identifier'): 'definition',
#  ((44, 13), (44, 14), '='): '=',
#  ((44, 15), (44, 23), 'function'): 'function',
#  ((44, 23), (44, 24), '('): '(',
#  ((44, 24), (44, 25), 'identifier'): 'x',
#  ((44, 25), (44, 26), ','): ',',
#  ((44, 27), (44, 32), 'identifier'): 'start',
#  ((44, 33), (44, 34), '='): '=',
#  ((44, 35), (44, 39), 'null'): 'NULL',
#  ((44, 39), (44, 40), ','): ',',
#  ((44, 41), (44, 44), 'identifier'): 'end',
#  ((44, 45), (44, 46), '='): '=',
#  ((44, 47), (44, 51), 'null'): 'NULL',
#  ((44, 51), (44, 52), ')'): ')',
#  ((44, 53), (44, 54), '{'): '{',
#  ((45, 4), (45, 6), 'if'): 'if',
#  ((45, 7), (45, 8), '('): '(',
#  ((45, 8), (45, 15), 'identifier'): 'is.null',
#  ((45, 15), (45, 16), '('): '(',
#  ((45, 16), (45, 21), 'identifier'): 'start',
#  ((45, 21), (45, 22), ')'): ')',
#  ((45, 22), (45, 23), ')'): ')',
#  ((45, 24), (45, 29), 'identifier'): 'start',
#  ((45, 30), (45, 32), '<-'): '<-',
#  ((45, 33), (45, 38), 'identifier'): 'start',
#  ((45, 38), (45, 39), '('): '(',
#  ((45, 39), (45, 40), 'identifier'): 'x',
#  ((45, 40), (45, 41), ')'): ')',
#  ((45, 41), (46, 0), '\n'): '',
#  ((46, 4), (46, 6), 'if'): 'if',
#  ((46, 7), (46, 8), '('): '(',
#  ((46, 8), (46, 15), 'identifier'): 'is.null',
#  ((46, 15), (46, 16), '('): '(',
#  ((46, 16), (46, 19), 'identifier'): 'end',
#  ((46, 19), (46, 20), ')'): ')',
#  ((46, 20), (46, 21), ')'): ')',
#  ((46, 22), (46, 25), 'identifier'): 'end',
#  ((46, 26), (46, 28), '<-'): '<-',
#  ((46, 29), (46, 32), 'identifier'): 'end',
#  ((46, 32), (46, 33), '('): '(',
#  ((46, 33), (46, 34), 'identifier'): 'x',
#  ((46, 34), (46, 35), ')'): ')',
#  ((46, 35), (47, 0), '\n'): '',
#  ((47, 4), (47, 9), 'identifier'): 'years',
#  ((47, 10), (47, 12), '<-'): '<-',
#  ((47, 13), (47, 17), 'identifier'): 'time',
#  ((47, 17), (47, 18), '('): '(',
#  ((47, 18), (47, 19), 'identifier'): 'x',
#  ((47, 19), (47, 20), ')'): ')',
#  ((47, 20), (49, 0), '\n'): '',
#  ((49, 4), (49, 5), 'identifier'): 'i',
#  ((49, 6), (49, 8), '<-'): '<-',
#  ((49, 9), (49, 14), 'identifier'): 'which',
#  ((49, 14), (49, 15), '('): '(',
#  ((49, 15), (49, 20), 'identifier'): 'years',
#  ((49, 21), (49, 23), '>='): '>=',
#  ((49, 24), (49, 29), 'identifier'): 'start',
#  ((49, 30), (49, 31), '&'): '&',
#  ((49, 32), (49, 37), 'identifier'): 'years',
#  ((49, 38), (49, 40), '<='): '<=',
#  ((49, 41), (49, 44), 'identifier'): 'end',
#  ((49, 44), (49, 45), ')'): ')',
#  ((49, 45), (50, 0), '\n'): '',
#  ((50, 4), (50, 5), 'identifier'): 'x',
#  ((50, 5), (50, 6), '['): '[',
#  ((50, 6), (50, 7), 'identifier'): 'i',
#  ((50, 7), (50, 8), ','): ',',
#  ((50, 9), (50, 10), ','): ',',
#  ((50, 11), (50, 15), 'identifier'): 'drop',
#  ((50, 16), (50, 17), '='): '=',
#  ((50, 18), (50, 23), 'false'): 'FALSE',
#  ((50, 23), (50, 24), ']'): ']',
#  ((50, 24), (51, 0), '\n'): '',
#  ((51, 2), (51, 3), '}'): '}',
#  ((52, 0), (52, 1), ')'): ')',
#  ((52, 1), (53, 0), '\n'): ''}

# %%
file_path = "jakeyeung/scChIX/"
rdpath = file_path + 'man/'
count = 0
for file in os.listdir(rdpath):
    print(rdpath+file)
    with open(rdpath+file, 'r') as rd:
        names = []
        document = ''
        flag = False
        Rfilename = []
        for lines in rd:
            if lines.__contains__(r'% Please edit documentation in R/'):
                d = re.split(r'\s+', lines)
                for item in d:
                    if item.__contains__(r'.r') or item.__contains__(r'.R'):
                        Rfilename.append(item.replace('R/','').replace(',','').replace('\n',''))
            if lines.__contains__(r'\name{'):
                names.append(lines[6:-2])
            if lines.__contains__(r'\alias{'):
                names.append(lines[7:-2])
            if lines.__contains__(r'\description{') or lines.__contains__(r'\details{'):
                flag = True
                continue
            if lines=='}\n':
                flag = False
            if flag:
                document = document + lines.replace('\n', ' ')

        print(Rfilename)
        print(names)
        for name in Rfilename:
            print(file_path+name)
            Rfile = open(file_path+name).read()
            tokens = get_type(parser, Rfile, r)
            fname = ''
            code = []
            t1 = None
            t2 = None
            t3 = None
            c1 = None
            c2 = None
            c3 = None
            codeF = False
            c = 0
            isChanged = False
            for key, value in tokens.items():
                print(key, value)
                t1 = t2
                t2 = t3
                t3 = key[2]
                c1 = c2
                c2 = c3
                c3 = value
                if t1 == 'identifier' and c1 in names and t2 == '<-' and t3 == 'function':
                    codeF = True
                    fname = c1
                if codeF:
                    code.append(value)
                    if value == '{':
                        c += 1
                        isChanged = True
                    if value == '}':
                        c -= 1

                    if c == 0 and isChanged:
                        with jsonlines.open(file_path+'functions.jsonl', mode='a') as writer:
                            json = {"func_name":fname, "code_token":code, "docstring":document}
                            writer.write(json)
                            count += 1
                        code = []
                        codeF = False
                        c = 0
                        isChanged = False
# Out:
# C:/Users/shawn/Desktop/R/R/jakeyeung/scChIX/man/ClipLast.Rd
# ['_aux.R']
# ['ClipLast', 'ClipLast']
# C:/Users/shawn/Desktop/R/R/jakeyeung/scChIX/_aux.R
# ((0, 0), (0, 12), 'comment') # Jake Yeung
# ((1, 0), (1, 30), 'comment') # Date of Creation: 2021-04-16
# ((2, 0), (2, 33), 'comment') # File: ~/projects/scChIX/R/aux.R
# ((3, 0), (3, 1), 'comment') #
# ((6, 0), (6, 16), 'identifier') AnnotateBins2.R4
# ((6, 17), (6, 19), '<-') <-
# ((6, 20), (6, 28), 'function') function
# ((6, 29), (6, 30), '(') (
# ((6, 30), (6, 39), 'identifier') terms.mat
# ((6, 39), (6, 40), ',') ,
# ((6, 41), (6, 50), 'identifier') top.thres
# ((6, 51), (6, 52), '=') =
# ((6, 53), (6, 58), 'float') 0.995
# ((6, 58), (6, 59), ',') ,
# ((6, 60), (6, 67), 'identifier') inf.tss
# ((6, 68), (6, 69), '=') =
# ((6, 70), (6, 130), 'string') "/Users/yeung/data/scchic/tables/gene_tss_winsize.50000.bed"
# ((6, 130), (6, 131), ',') ,
# ((7, 30), (7, 34), 'identifier') txdb
# ((7, 35), (7, 36), '=') =
# ((7, 37), (7, 71), 'identifier') TxDb.Mmusculus.UCSC.mm10.knownGene
# ((7, 71), (7, 72), ',') ,
# ((7, 73), (7, 79), 'identifier') annodb
# ((7, 80), (7, 81), '=') =
# ((7, 82), (7, 96), 'string') "org.Mm.eg.db"
# ((7, 96), (7, 97), ',') ,
# ((8, 30), (8, 42), 'identifier') chromos.keep
# ((8, 43), (8, 44), '=') =
# ((8, 45), (8, 46), 'identifier') c
# ((8, 46), (8, 47), '(') (
# ((8, 47), (8, 52), 'identifier') paste
# ((8, 52), (8, 53), '(') (
# ((8, 53), (8, 58), 'string') "chr"
# ((8, 58), (8, 59), ',') ,
# ((8, 60), (8, 63), 'identifier') seq
# ((8, 63), (8, 64), '(') (
# ((8, 64), (8, 66), 'float') 19
# ((8, 66), (8, 67), ')') )
# ((8, 67), (8, 68), ',') ,
# ((8, 69), (8, 72), 'identifier') sep
# ((8, 73), (8, 74), '=') =
# ((8, 75), (8, 77), 'string') ""
# ((8, 77), (8, 78), ')') )
# ((8, 78), (8, 79), ',') ,
# ((8, 80), (8, 86), 'string') "chrX"
# ((8, 86), (8, 87), ',') ,
# ((9, 47), (9, 53), 'string') "chrY"
# ((9, 53), (9, 54), ')') )
# ((9, 54), (9, 55), ',') ,
# ((9, 56), (9, 66), 'identifier') skip.split
# ((9, 67), (9, 68), '=') =
# ((9, 69), (9, 74), 'false') FALSE
# ((9, 74), (9, 75), ')') )
# ((10, 0), (10, 1), '{') {
# ((11, 2), (11, 12), 'identifier') assertthat
# ((11, 12), (11, 14), '::') ::
# ((11, 14), (11, 25), 'identifier') assert_that
# ((11, 25), (11, 26), '(') (
# ((11, 26), (11, 37), 'identifier') file.exists
# ((11, 37), (11, 38), '(') (
# ((11, 38), (11, 45), 'identifier') inf.tss
# ((11, 45), (11, 46), ')') )
# ((11, 46), (11, 47), ')') )
# ((11, 47), (12, 0), '\n')
# ((12, 2), (12, 57), 'comment') # assertthat::assert_that(class(terms.mat) == "matrix")
# ((13, 2), (13, 9), 'identifier') regions
# ((13, 10), (13, 12), '<-') <-
# ((13, 13), (13, 23), 'identifier') data.frame
# ((13, 23), (13, 24), '(') (
# ((13, 24), (13, 32), 'identifier') seqnames
# ((13, 33), (13, 34), '=') =
# ((13, 35), (13, 41), 'identifier') sapply
# ((13, 41), (13, 42), '(') (
# ((13, 42), (13, 50), 'identifier') colnames
# ((13, 50), (13, 51), '(') (
# ((13, 51), (13, 60), 'identifier') terms.mat
# ((13, 60), (13, 61), ')') )
# ((13, 61), (13, 62), ',') ,
# ((14, 42), (14, 51), 'identifier') GetChromo
# ((14, 51), (14, 52), ')') )
# ((14, 52), (14, 53), ',') ,
# ((14, 54), (14, 59), 'identifier') start
# ((14, 60), (14, 61), '=') =
# ((14, 62), (14, 68), 'identifier') sapply
# ((14, 68), (14, 69), '(') (
# ((14, 69), (14, 77), 'identifier') colnames
# ((14, 77), (14, 78), '(') (
# ((14, 78), (14, 87), 'identifier') terms.mat
# ((14, 87), (14, 88), ')') )
# ((14, 88), (14, 89), ',') ,
# ((14, 90), (14, 98), 'identifier') GetStart
# ((14, 98), (14, 99), ')') )
# ((14, 99), (14, 100), ',') ,
# ((15, 24), (15, 27), 'identifier') end
# ((15, 28), (15, 29), '=') =
# ((15, 30), (15, 36), 'identifier') sapply
# ((15, 36), (15, 37), '(') (
# ((15, 37), (15, 45), 'identifier') colnames
# ((15, 45), (15, 46), '(') (
# ((15, 46), (15, 55), 'identifier') terms.mat
# ((15, 55), (15, 56), ')') )
# ((15, 56), (15, 57), ',') ,
# ((15, 58), (15, 64), 'identifier') GetEnd
# ((15, 64), (15, 65), ')') )
# ((15, 65), (15, 66), ',') ,
# ((15, 67), (15, 83), 'identifier') stringsAsFactors
# ((15, 84), (15, 85), '=') =
# ((15, 86), (15, 91), 'false') FALSE
# ((15, 91), (15, 92), ')') )
# ((15, 92), (16, 0), '\n')
# ((16, 2), (16, 10), 'identifier') rownames
# ((16, 10), (16, 11), '(') (
# ((16, 11), (16, 18), 'identifier') regions
# ((16, 18), (16, 19), ')') )
# ((16, 20), (16, 22), '<-') <-
# ((16, 23), (16, 31), 'identifier') colnames
# ((16, 31), (16, 32), '(') (
# ((16, 32), (16, 41), 'identifier') terms.mat
# ((16, 41), (16, 42), ')') )
# ((16, 42), (17, 0), '\n')
# ((17, 2), (17, 7), 'identifier') print
# ((17, 7), (17, 8), '(') (
# ((17, 8), (17, 25), 'string') "Chromos to keep"
# ((17, 25), (17, 26), ')') )
# ((17, 26), (18, 0), '\n')
# ((18, 2), (18, 7), 'identifier') print
# ((18, 7), (18, 8), '(') (
# ((18, 8), (18, 20), 'identifier') chromos.keep
# ((18, 20), (18, 21), ')') )
# ((18, 21), (19, 0), '\n')
# ((19, 2), (19, 9), 'identifier') regions
# ((19, 10), (19, 12), '<-') <-
# ((19, 13), (19, 19), 'identifier') subset
# ((19, 19), (19, 20), '(') (
# ((19, 20), (19, 27), 'identifier') regions
# ((19, 27), (19, 28), ',') ,
# ((19, 29), (19, 37), 'identifier') seqnames
# ((19, 38), (19, 39), '%') %
# ((19, 41), (19, 42), '%') %
# ((19, 43), (19, 55), 'identifier') chromos.keep
# ((19, 55), (19, 56), ')') )
# ((19, 56), (20, 0), '\n')
# ((20, 2), (20, 15), 'identifier') regions.range
# ((20, 16), (20, 18), '<-') <-
# ((20, 19), (20, 43), 'identifier') makeGRangesFromDataFrame
# ((20, 43), (20, 44), '(') (
# ((20, 44), (20, 57), 'identifier') as.data.frame
# ((20, 57), (20, 58), '(') (
# ((20, 58), (20, 65), 'identifier') regions
# ((20, 65), (20, 66), ')') )
# ((20, 66), (20, 67), ')') )
# ((20, 67), (21, 0), '\n')
# ((21, 2), (21, 19), 'identifier') regions.annotated
# ((21, 20), (21, 22), '<-') <-
# ((21, 23), (21, 36), 'identifier') as.data.frame
# ((21, 36), (21, 37), '(') (
# ((21, 37), (21, 49), 'identifier') annotatePeak
# ((21, 49), (21, 50), '(') (
# ((21, 50), (21, 63), 'identifier') regions.range
# ((21, 63), (21, 64), ',') ,
# ((22, 50), (22, 54), 'identifier') TxDb
# ((22, 55), (22, 56), '=') =
# ((22, 57), (22, 61), 'identifier') txdb
# ((22, 61), (22, 62), ',') ,
# ((22, 63), (22, 69), 'identifier') annoDb
# ((22, 70), (22, 71), '=') =
# ((22, 72), (22, 78), 'identifier') annodb
# ((22, 78), (22, 79), ')') )
# ((22, 79), (22, 80), ')') )
# ((22, 80), (23, 0), '\n')
# ((23, 2), (23, 19), 'identifier') regions.annotated
# ((23, 19), (23, 20), '$') $
# ((23, 20), (23, 32), 'identifier') region_coord
# ((23, 33), (23, 35), '<-') <-
# ((23, 36), (23, 41), 'identifier') names
# ((23, 41), (23, 42), '(') (
# ((23, 42), (23, 55), 'identifier') regions.range
# ((23, 55), (23, 56), ')') )
# ((23, 56), (24, 0), '\n')
# ((24, 2), (24, 15), 'identifier') topic.regions
# ((24, 16), (24, 18), '<-') <-
# ((24, 19), (24, 25), 'identifier') lapply
# ((24, 25), (24, 26), '(') (
# ((24, 26), (24, 29), 'identifier') seq
# ((24, 29), (24, 30), '(') (
# ((24, 30), (24, 34), 'identifier') nrow
# ((24, 34), (24, 35), '(') (
# ((24, 35), (24, 44), 'identifier') terms.mat
# ((24, 44), (24, 45), ')') )
# ((24, 45), (24, 46), ')') )
# ((24, 46), (24, 47), ',') ,
# ((24, 48), (24, 56), 'function') function
# ((24, 56), (24, 57), '(') (
# ((24, 57), (24, 61), 'identifier') clst
# ((24, 61), (24, 62), ')') )
# ((24, 63), (24, 64), '{') {
# ((25, 4), (25, 10), 'identifier') return
# ((25, 10), (25, 11), '(') (
# ((25, 11), (25, 27), 'identifier') SelectTopRegions
# ((25, 27), (25, 28), '(') (
# ((25, 28), (25, 37), 'identifier') terms.mat
# ((25, 37), (25, 38), '[') [
# ((25, 38), (25, 42), 'identifier') clst
# ((25, 42), (25, 43), ',') ,
# ((25, 44), (25, 45), ']') ]
# ((25, 45), (25, 46), ',') ,
# ((25, 47), (25, 55), 'identifier') colnames
# ((25, 55), (25, 56), '(') (
# ((25, 56), (25, 65), 'identifier') terms.mat
# ((25, 65), (25, 66), ')') )
# ((25, 66), (25, 67), ',') ,
# ((26, 28), (26, 34), 'identifier') method
# ((26, 35), (26, 36), '=') =
# ((26, 37), (26, 44), 'string') "thres"
# ((26, 44), (26, 45), ',') ,
# ((26, 46), (26, 56), 'identifier') method.val
# ((26, 57), (26, 58), '=') =
# ((26, 59), (26, 68), 'identifier') top.thres
# ((26, 68), (26, 69), ')') )
# ((26, 69), (26, 70), ')') )
# ((26, 70), (27, 0), '\n')
# ((27, 2), (27, 3), '}') }
# ((27, 3), (27, 4), ')') )
# ((27, 4), (28, 0), '\n')
# ((28, 2), (28, 7), 'identifier') print
# ((28, 7), (28, 8), '(') (
# ((28, 8), (28, 13), 'identifier') paste
# ((28, 13), (28, 14), '(') (
# ((28, 14), (28, 43), 'string') "Using TSS definitions from:"
# ((28, 43), (28, 44), ',') ,
# ((28, 45), (28, 52), 'identifier') inf.tss
# ((28, 52), (28, 53), ')') )
# ((28, 53), (28, 54), ')') )
# ((28, 54), (29, 0), '\n')
# ((29, 2), (29, 12), 'identifier') terms.long
# ((29, 13), (29, 15), '<-') <-
# ((29, 16), (29, 26), 'identifier') data.frame
# ((29, 26), (29, 27), '(') (
# ((29, 27), (29, 31), 'identifier') term
# ((29, 32), (29, 33), '=') =
# ((29, 34), (29, 42), 'identifier') colnames
# ((29, 42), (29, 43), '(') (
# ((29, 43), (29, 52), 'identifier') terms.mat
# ((29, 52), (29, 53), ')') )
# ((29, 53), (29, 54), ',') ,
# ((29, 55), (29, 68), 'identifier') as.data.frame
# ((29, 68), (29, 69), '(') (
# ((29, 69), (29, 70), 'identifier') t
# ((29, 70), (29, 71), '(') (
# ((29, 71), (29, 80), 'identifier') terms.mat
# ((29, 80), (29, 81), ')') )
# ((29, 81), (29, 82), ')') )
# ((29, 82), (29, 83), ',') ,
# ((30, 27), (30, 43), 'identifier') stringsAsFactors
# ((30, 44), (30, 45), '=') =
# ((30, 46), (30, 51), 'false') FALSE
# ((30, 51), (30, 52), ')') )
# ((30, 53), (30, 54), '%') %
# ((30, 55), (30, 56), '%') %
# ((30, 57), (30, 63), 'identifier') gather
# ((30, 63), (30, 64), '(') (
# ((30, 64), (30, 67), 'identifier') key
# ((30, 68), (30, 69), '=') =
# ((30, 70), (30, 77), 'string') "topic"
# ((30, 77), (30, 78), ',') ,
# ((30, 79), (30, 84), 'identifier') value
# ((30, 85), (30, 86), '=') =
# ((30, 87), (30, 95), 'string') "weight"
# ((30, 95), (30, 96), ',') ,
# ((31, 64), (31, 65), '-') -
# ((31, 65), (31, 69), 'identifier') term
# ((31, 69), (31, 70), ')') )
# ((31, 71), (31, 72), '%') %
# ((31, 73), (31, 74), '%') %
# ((31, 75), (31, 81), 'identifier') mutate
# ((31, 81), (31, 82), '(') (
# ((31, 82), (31, 87), 'identifier') topic
# ((31, 88), (31, 89), '=') =
# ((31, 90), (31, 94), 'identifier') gsub
# ((31, 94), (31, 95), '(') (
# ((31, 95), (31, 98), 'string') "X"
# ((31, 98), (31, 99), ',') ,
# ((31, 100), (31, 102), 'string') ""
# ((31, 102), (31, 103), ',') ,
# ((31, 104), (31, 109), 'identifier') topic
# ((31, 109), (31, 110), ')') )
# ((31, 110), (31, 111), ')') )
# ((31, 112), (31, 113), '%') %
# ((31, 114), (31, 115), '%') %
# ((31, 116), (31, 124), 'identifier') group_by
# ((31, 124), (31, 125), '(') (
# ((31, 125), (31, 130), 'identifier') topic
# ((31, 130), (31, 131), ')') )
# ((31, 132), (31, 133), '%') %
# ((31, 134), (31, 135), '%') %
# ((32, 4), (32, 11), 'identifier') arrange
# ((32, 11), (32, 12), '(') (
# ((32, 12), (32, 16), 'identifier') desc
# ((32, 16), (32, 17), '(') (
# ((32, 17), (32, 23), 'identifier') weight
# ((32, 23), (32, 24), ')') )
# ((32, 24), (32, 25), ')') )
# ((32, 26), (32, 27), '%') %
# ((32, 28), (32, 29), '%') %
# ((32, 30), (32, 36), 'identifier') mutate
# ((32, 36), (32, 37), '(') (
# ((32, 37), (32, 40), 'identifier') rnk
# ((32, 41), (32, 42), '=') =
# ((32, 43), (32, 46), 'identifier') seq
# ((32, 46), (32, 47), '(') (
# ((32, 47), (32, 53), 'identifier') length
# ((32, 53), (32, 54), '(') (
# ((32, 54), (32, 60), 'identifier') weight
# ((32, 60), (32, 61), ')') )
# ((32, 61), (32, 62), ')') )
# ((32, 62), (32, 63), ')') )
# ((32, 64), (32, 65), '%') %
# ((32, 66), (32, 67), '%') %
# ((33, 4), (33, 11), 'identifier') rowwise
# ((33, 11), (33, 12), '(') (
# ((33, 12), (33, 13), ')') )
# ((33, 13), (34, 0), '\n')
# ((34, 2), (34, 16), 'identifier') terms.filt.top
# ((34, 17), (34, 19), '<-') <-
# ((34, 20), (34, 30), 'identifier') terms.long
# ((34, 31), (34, 32), '%') %
# ((34, 33), (34, 34), '%') %
# ((34, 35), (34, 42), 'identifier') rowwise
# ((34, 42), (34, 43), '(') (
# ((34, 43), (34, 44), ')') )
# ((34, 44), (35, 0), '\n')
# ((35, 2), (35, 9), 'identifier') tss.dat
# ((35, 10), (35, 12), '<-') <-
# ((35, 13), (35, 18), 'identifier') fread
# ((35, 18), (35, 19), '(') (
# ((35, 19), (35, 26), 'identifier') inf.tss
# ((35, 26), (35, 27), ',') ,
# ((35, 28), (35, 37), 'identifier') col.names
# ((35, 38), (35, 39), '=') =
# ((35, 40), (35, 41), 'identifier') c
# ((35, 41), (35, 42), '(') (
# ((35, 42), (35, 52), 'string') "seqnames"
# ((35, 52), (35, 53), ',') ,
# ((35, 54), (35, 61), 'string') "start"
# ((35, 61), (35, 62), ',') ,
# ((36, 42), (36, 47), 'string') "end"
# ((36, 47), (36, 48), ',') ,
# ((36, 49), (36, 58), 'string') "tssname"
# ((36, 58), (36, 59), ')') )
# ((36, 59), (36, 60), ')') )
# ((36, 60), (37, 0), '\n')
# ((37, 2), (37, 9), 'identifier') tss.dat
# ((37, 9), (37, 10), '$') $
# ((37, 10), (37, 14), 'identifier') gene
# ((37, 15), (37, 17), '<-') <-
# ((37, 18), (37, 24), 'identifier') sapply
# ((37, 24), (37, 25), '(') (
# ((37, 25), (37, 32), 'identifier') tss.dat
# ((37, 32), (37, 33), '$') $
# ((37, 33), (37, 40), 'identifier') tssname
# ((37, 40), (37, 41), ',') ,
# ((37, 42), (37, 50), 'function') function
# ((37, 50), (37, 51), '(') (
# ((37, 51), (37, 52), 'identifier') x
# ((37, 52), (37, 53), ')') )
# ((37, 54), (37, 62), 'identifier') strsplit
# ((37, 62), (37, 63), '(') (
# ((37, 63), (37, 64), 'identifier') x
# ((37, 64), (37, 65), ',') ,
# ((38, 63), (38, 66), 'string') ";"
# ((38, 66), (38, 67), ')') )
# ((38, 67), (38, 69), '[[') [[
# ((38, 69), (38, 70), 'float') 1
# ((38, 70), (38, 72), ']]') ]]
# ((38, 72), (38, 74), '[[') [[
# ((38, 74), (38, 75), 'float') 2
# ((38, 75), (38, 77), ']]') ]]
# ((38, 77), (38, 78), ')') )
# ((38, 78), (39, 0), '\n')
# ((39, 2), (39, 16), 'identifier') annots.biomart
# ((39, 17), (39, 19), '<-') <-
# ((39, 20), (39, 37), 'identifier') regions.annotated
# ((39, 38), (39, 39), '%') %
# ((39, 40), (39, 41), '%') %
# ((39, 42), (39, 48), 'identifier') mutate
# ((39, 48), (39, 49), '(') (
# ((39, 49), (39, 54), 'identifier') midpt
# ((39, 55), (39, 56), '=') =
# ((39, 57), (39, 62), 'identifier') start
# ((39, 63), (39, 64), '+') +
# ((40, 51), (40, 52), '(') (
# ((40, 52), (40, 55), 'identifier') end
# ((40, 56), (40, 57), '-') -
# ((40, 58), (40, 63), 'identifier') start
# ((40, 63), (40, 64), ')') )
# ((40, 64), (40, 65), '/') /
# ((40, 65), (40, 66), 'float') 2
# ((40, 66), (40, 67), ')') )
# ((40, 68), (40, 69), '%') %
# ((40, 70), (40, 71), '%') %
# ((40, 72), (40, 78), 'identifier') filter
# ((40, 78), (40, 79), '(') (
# ((40, 79), (40, 91), 'identifier') region_coord
# ((40, 92), (40, 93), '%') %
# ((40, 95), (40, 96), '%') %
# ((40, 97), (40, 111), 'identifier') terms.filt.top
# ((40, 111), (40, 112), '$') $
# ((40, 112), (40, 116), 'identifier') term
# ((40, 116), (40, 117), ')') )
# ((40, 117), (41, 0), '\n')
# ((41, 2), (41, 11), 'identifier') annots.gr
# ((41, 12), (41, 14), '<-') <-
# ((41, 15), (41, 39), 'identifier') makeGRangesFromDataFrame
# ((41, 39), (41, 40), '(') (
# ((41, 40), (41, 54), 'identifier') annots.biomart
# ((41, 55), (41, 56), '%') %
# ((41, 57), (41, 58), '%') %
# ((42, 42), (42, 47), 'identifier') dplyr
# ((42, 47), (42, 49), '::') ::
# ((42, 49), (42, 55), 'identifier') select
# ((42, 55), (42, 56), '(') (
# ((42, 56), (42, 64), 'identifier') seqnames
# ((42, 64), (42, 65), ',') ,
# ((42, 66), (42, 71), 'identifier') start
# ((42, 71), (42, 72), ',') ,
# ((42, 73), (42, 76), 'identifier') end
# ((42, 76), (42, 77), ',') ,
# ((42, 78), (42, 84), 'identifier') SYMBOL
# ((42, 84), (42, 85), ',') ,
# ((42, 86), (42, 98), 'identifier') region_coord
# ((42, 98), (42, 99), ',') ,
# ((43, 56), (43, 63), 'identifier') ENSEMBL
# ((43, 63), (43, 64), ')') )
# ((43, 64), (43, 65), ',') ,
# ((43, 66), (43, 84), 'identifier') keep.extra.columns
# ((43, 85), (43, 86), '=') =
# ((43, 87), (43, 91), 'true') TRUE
# ((43, 91), (43, 92), ')') )
# ((43, 92), (44, 0), '\n')
# ((44, 2), (44, 15), 'identifier') annots.tss.gr
# ((44, 16), (44, 18), '<-') <-
# ((44, 19), (44, 43), 'identifier') makeGRangesFromDataFrame
# ((44, 43), (44, 44), '(') (
# ((44, 44), (44, 51), 'identifier') tss.dat
# ((44, 51), (44, 52), ',') ,
# ((44, 53), (44, 71), 'identifier') keep.extra.columns
# ((44, 72), (44, 73), '=') =
# ((44, 74), (44, 78), 'true') TRUE
# ((44, 78), (44, 79), ')') )
# ((44, 79), (45, 0), '\n')
# ((45, 2), (45, 5), 'identifier') out
# ((45, 6), (45, 8), '<-') <-
# ((45, 9), (45, 21), 'identifier') findOverlaps
# ((45, 21), (45, 22), '(') (
# ((45, 22), (45, 35), 'identifier') annots.tss.gr
# ((45, 35), (45, 36), ',') ,
# ((45, 37), (45, 46), 'identifier') annots.gr
# ((45, 46), (45, 47), ',') ,
# ((45, 48), (45, 52), 'identifier') type
# ((45, 53), (45, 54), '=') =
# ((45, 55), (45, 63), 'string') "within"
# ((45, 63), (45, 64), ')') )
# ((45, 64), (46, 0), '\n')
# ((46, 2), (46, 6), 'identifier') out2
# ((46, 7), (46, 9), '<-') <-
# ((46, 10), (46, 22), 'identifier') findOverlaps
# ((46, 22), (46, 23), '(') (
# ((46, 23), (46, 32), 'identifier') annots.gr
# ((46, 32), (46, 33), ',') ,
# ((46, 34), (46, 47), 'identifier') annots.tss.gr
# ((46, 47), (46, 48), ',') ,
# ((46, 49), (46, 53), 'identifier') type
# ((46, 54), (46, 55), '=') =
# ((46, 56), (46, 61), 'string') "any"
# ((46, 61), (46, 62), ')') )
# ((46, 62), (47, 0), '\n')
# ((47, 2), (47, 9), 'identifier') out2.df
# ((47, 10), (47, 11), '=') =
# ((47, 12), (47, 22), 'identifier') data.frame
# ((47, 22), (47, 23), '(') (
# ((47, 23), (47, 32), 'identifier') annots.gr
# ((47, 32), (47, 33), '[') [
# ((47, 33), (47, 42), 'identifier') queryHits
# ((47, 42), (47, 43), '(') (
# ((47, 43), (47, 47), 'identifier') out2
# ((47, 47), (47, 48), ')') )
# ((47, 48), (47, 49), ',') ,
# ((47, 50), (47, 51), ']') ]
# ((47, 51), (47, 52), ',') ,
# ((47, 53), (47, 66), 'identifier') annots.tss.gr
# ((47, 66), (47, 67), '[') [
# ((47, 67), (47, 78), 'identifier') subjectHits
# ((47, 78), (47, 79), '(') (
# ((47, 79), (47, 83), 'identifier') out2
# ((47, 83), (47, 84), ')') )
# ((47, 84), (47, 85), ',') ,
# ((48, 2), (48, 3), ']') ]
# ((48, 3), (48, 4), ')') )
# ((48, 5), (48, 6), '%') %
# ((48, 7), (48, 8), '%') %
# ((48, 9), (48, 15), 'identifier') mutate
# ((48, 15), (48, 16), '(') (
# ((48, 16), (48, 21), 'identifier') midpt
# ((48, 22), (48, 23), '=') =
# ((48, 24), (48, 29), 'identifier') start
# ((48, 30), (48, 31), '+') +
# ((48, 32), (48, 37), 'identifier') round
# ((48, 37), (48, 38), '(') (
# ((48, 38), (48, 43), 'identifier') width
# ((48, 43), (48, 44), '/') /
# ((48, 44), (48, 45), 'float') 2
# ((48, 45), (48, 46), ')') )
# ((48, 46), (48, 47), ',') ,
# ((48, 48), (48, 55), 'identifier') midpt.1
# ((48, 56), (48, 57), '=') =
# ((48, 58), (48, 65), 'identifier') start.1
# ((48, 66), (48, 67), '+') +
# ((49, 18), (49, 23), 'identifier') round
# ((49, 23), (49, 24), '(') (
# ((49, 24), (49, 31), 'identifier') width.1
# ((49, 31), (49, 32), '/') /
# ((49, 32), (49, 33), 'float') 2
# ((49, 33), (49, 34), ')') )
# ((49, 34), (49, 35), ',') ,
# ((49, 36), (49, 47), 'identifier') dist.to.tss
# ((49, 48), (49, 49), '=') =
# ((49, 50), (49, 57), 'identifier') midpt.1
# ((49, 58), (49, 59), '-') -
# ((49, 60), (49, 65), 'identifier') midpt
# ((49, 65), (49, 66), ')') )
# ((49, 66), (50, 0), '\n')
# ((50, 2), (50, 17), 'identifier') out2.df.closest
# ((50, 18), (50, 20), '<-') <-
# ((50, 21), (50, 28), 'identifier') out2.df
# ((50, 29), (50, 30), '%') %
# ((50, 31), (50, 32), '%') %
# ((50, 33), (50, 41), 'identifier') group_by
# ((50, 41), (50, 42), '(') (
# ((50, 42), (50, 54), 'identifier') region_coord
# ((50, 54), (50, 55), ')') )
# ((50, 56), (50, 57), '%') %
# ((50, 58), (50, 59), '%') %
# ((51, 4), (51, 10), 'identifier') filter
# ((51, 10), (51, 11), '(') (
# ((51, 11), (51, 14), 'identifier') abs
# ((51, 14), (51, 15), '(') (
# ((51, 15), (51, 26), 'identifier') dist.to.tss
# ((51, 26), (51, 27), ')') )
# ((51, 28), (51, 30), '==') ==
# ((51, 31), (51, 34), 'identifier') min
# ((51, 34), (51, 35), '(') (
# ((51, 35), (51, 38), 'identifier') abs
# ((51, 38), (51, 39), '(') (
# ((51, 39), (51, 50), 'identifier') dist.to.tss
# ((51, 50), (51, 51), ')') )
# ((51, 51), (51, 52), ')') )
# ((51, 52), (51, 53), ')') )
# ((51, 53), (52, 0), '\n')
# ((52, 2), (52, 11), 'identifier') terms.new
# ((52, 12), (52, 14), '<-') <-
# ((52, 15), (52, 20), 'identifier') paste
# ((52, 20), (52, 21), '(') (
# ((52, 21), (52, 36), 'identifier') out2.df.closest
# ((52, 36), (52, 37), '$') $
# ((52, 37), (52, 49), 'identifier') region_coord
# ((52, 49), (52, 50), ',') ,
# ((52, 51), (52, 66), 'identifier') out2.df.closest
# ((52, 66), (52, 67), '$') $
# ((52, 67), (52, 71), 'identifier') gene
# ((52, 71), (52, 72), ',') ,
# ((53, 21), (53, 24), 'identifier') sep
# ((53, 25), (53, 26), '=') =
# ((53, 27), (53, 30), 'string') ";"
# ((53, 30), (53, 31), ')') )
# ((53, 31), (54, 0), '\n')
# ((54, 2), (54, 12), 'identifier') terms.hash
# ((54, 13), (54, 15), '<-') <-
# ((54, 16), (54, 20), 'identifier') hash
# ((54, 20), (54, 22), '::') ::
# ((54, 22), (54, 26), 'identifier') hash
# ((54, 26), (54, 27), '(') (
# ((54, 27), (54, 42), 'identifier') out2.df.closest
# ((54, 42), (54, 43), '$') $
# ((54, 43), (54, 55), 'identifier') region_coord
# ((54, 55), (54, 56), ',') ,
# ((54, 57), (54, 66), 'identifier') terms.new
# ((54, 66), (54, 67), ')') )
# ((54, 67), (55, 0), '\n')
# ((55, 2), (55, 13), 'identifier') terms.annot
# ((55, 14), (55, 16), '<-') <-
# ((55, 17), (55, 31), 'identifier') terms.filt.top
# ((55, 32), (55, 33), '%') %
# ((55, 34), (55, 35), '%') %
# ((55, 36), (55, 42), 'identifier') mutate
# ((55, 42), (55, 43), '(') (
# ((55, 43), (55, 51), 'identifier') termgene
# ((55, 52), (55, 53), '=') =
# ((55, 54), (55, 60), 'identifier') ifelse
# ((55, 60), (55, 61), '(') (
# ((55, 61), (55, 62), '!') !
# ((55, 62), (55, 69), 'identifier') is.null
# ((55, 69), (55, 70), '(') (
# ((55, 70), (55, 80), 'identifier') terms.hash
# ((55, 80), (55, 82), '[[') [[
# ((55, 82), (55, 86), 'identifier') term
# ((55, 86), (55, 88), ']]') ]]
# ((55, 88), (55, 89), ')') )
# ((55, 89), (55, 90), ',') ,
# ((56, 61), (56, 71), 'identifier') terms.hash
# ((56, 71), (56, 73), '[[') [[
# ((56, 73), (56, 77), 'identifier') term
# ((56, 77), (56, 79), ']]') ]]
# ((56, 79), (56, 80), ',') ,
# ((56, 81), (56, 83), 'NA') NA
# ((56, 83), (56, 84), ')') )
# ((56, 84), (56, 85), ')') )
# ((56, 85), (57, 0), '\n')
# ((57, 2), (57, 12), 'identifier') terms.filt
# ((57, 13), (57, 15), '<-') <-
# ((57, 16), (57, 30), 'identifier') terms.filt.top
# ((57, 31), (57, 32), '%') %
# ((57, 33), (57, 34), '%') %
# ((57, 35), (57, 41), 'identifier') mutate
# ((57, 41), (57, 42), '(') (
# ((57, 42), (57, 50), 'identifier') termgene
# ((57, 51), (57, 52), '=') =
# ((57, 53), (57, 59), 'identifier') ifelse
# ((57, 59), (57, 60), '(') (
# ((57, 60), (57, 61), '!') !
# ((57, 61), (57, 68), 'identifier') is.null
# ((57, 68), (57, 69), '(') (
# ((57, 69), (57, 79), 'identifier') terms.hash
# ((57, 79), (57, 81), '[[') [[
# ((57, 81), (57, 85), 'identifier') term
# ((57, 85), (57, 87), ']]') ]]
# ((57, 87), (57, 88), ')') )
# ((57, 88), (57, 89), ',') ,
# ((58, 60), (58, 70), 'identifier') terms.hash
# ((58, 70), (58, 72), '[[') [[
# ((58, 72), (58, 76), 'identifier') term
# ((58, 76), (58, 78), ']]') ]]
# ((58, 78), (58, 79), ',') ,
# ((58, 80), (58, 82), 'NA') NA
# ((58, 82), (58, 83), ')') )
# ((58, 83), (58, 84), ')') )
# ((58, 85), (58, 86), '%') %
# ((58, 87), (58, 88), '%') %
# ((58, 89), (58, 95), 'identifier') filter
# ((58, 95), (58, 96), '(') (
# ((58, 96), (58, 97), '!') !
# ((58, 97), (58, 102), 'identifier') is.na
# ((58, 102), (58, 103), '(') (
# ((58, 103), (58, 111), 'identifier') termgene
# ((58, 111), (58, 112), ')') )
# ((58, 112), (58, 113), ')') )
# ((58, 113), (59, 0), '\n')
# ((59, 2), (59, 4), 'if') if
# ((59, 5), (59, 6), '(') (
# ((59, 6), (59, 7), '!') !
# ((59, 7), (59, 17), 'identifier') skip.split
# ((59, 17), (59, 18), ')') )
# ((59, 19), (59, 20), '{') {
# ((60, 4), (60, 14), 'identifier') terms.filt
# ((60, 15), (60, 17), '<-') <-
# ((60, 18), (60, 28), 'identifier') terms.filt
# ((60, 29), (60, 30), '%') %
# ((60, 31), (60, 32), '%') %
# ((60, 33), (60, 39), 'identifier') mutate
# ((60, 39), (60, 40), '(') (
# ((60, 40), (60, 44), 'identifier') gene
# ((60, 45), (60, 46), '=') =
# ((60, 47), (60, 53), 'identifier') sapply
# ((60, 53), (60, 54), '(') (
# ((60, 54), (60, 62), 'identifier') termgene
# ((60, 62), (60, 63), ',') ,
# ((61, 54), (61, 62), 'function') function
# ((61, 62), (61, 63), '(') (
# ((61, 63), (61, 64), 'identifier') x
# ((61, 64), (61, 65), ')') )
# ((61, 66), (61, 74), 'identifier') strsplit
# ((61, 74), (61, 75), '(') (
# ((61, 75), (61, 76), 'identifier') x
# ((61, 76), (61, 77), ',') ,
# ((61, 78), (61, 81), 'string') ";"
# ((61, 81), (61, 82), ')') )
# ((61, 82), (61, 84), '[[') [[
# ((61, 84), (61, 85), 'float') 1
# ((61, 85), (61, 87), ']]') ]]
# ((61, 87), (61, 89), '[[') [[
# ((61, 89), (61, 90), 'float') 2
# ((61, 90), (61, 92), ']]') ]]
# ((61, 92), (61, 93), ')') )
# ((61, 93), (61, 94), ')') )
# ((61, 95), (61, 96), '%') %
# ((61, 97), (61, 98), '%') %
# ((61, 99), (61, 107), 'identifier') group_by
# ((61, 107), (61, 108), '(') (
# ((61, 108), (61, 112), 'identifier') gene
# ((61, 112), (61, 113), ')') )
# ((61, 113), (62, 0), '\n')
# ((62, 2), (62, 3), '}') }
# ((62, 3), (63, 0), '\n')
# ((63, 2), (63, 8), 'identifier') return
# ((63, 8), (63, 9), '(') (
# ((63, 9), (63, 13), 'identifier') list
# ((63, 13), (63, 14), '(') (
# ((63, 14), (63, 27), 'identifier') topic.regions
# ((63, 28), (63, 29), '=') =
# ((63, 30), (63, 43), 'identifier') topic.regions
# ((63, 43), (63, 44), ',') ,
# ((63, 45), (63, 62), 'identifier') regions.annotated
# ((63, 63), (63, 64), '=') =
# ((63, 65), (63, 82), 'identifier') regions.annotated
# ((63, 82), (63, 83), ',') ,
# ((64, 14), (64, 25), 'identifier') terms.annot
# ((64, 26), (64, 27), '=') =
# ((64, 28), (64, 39), 'identifier') terms.annot
# ((64, 39), (64, 40), ',') ,
# ((64, 41), (64, 56), 'identifier') out2.df.closest
# ((64, 57), (64, 58), '=') =
# ((64, 59), (64, 74), 'identifier') out2.df.closest
# ((64, 74), (64, 75), ',') ,
# ((65, 14), (65, 24), 'identifier') terms.filt
# ((65, 25), (65, 26), '=') =
# ((65, 27), (65, 37), 'identifier') terms.filt
# ((65, 37), (65, 38), ')') )
# ((65, 38), (65, 39), ')') )
# ((65, 39), (66, 0), '\n')
# ((66, 0), (66, 1), '}') }
# ((66, 1), (68, 0), '\n')
# ((68, 0), (68, 95), 'comment') #' Clips out string after the last separator. eg B6-13W1-BM-H3K4me3-1_269 -> B6-13W1-BM-H3K4me3
# ((69, 0), (69, 3), 'comment') #'
# ((70, 0), (70, 72), 'comment') #' @param x string containing a separator and text you want you clip out
# ((71, 0), (71, 130), 'comment') #' @param jsep separator, such as dash or underscore that matches in the text. If matches multiple times, will take the last match
# ((72, 0), (72, 118), 'comment') #' @param jsep.out Output separator, important if clipping "." you want to input "\\." to escape the special character
# ((73, 0), (73, 61), 'comment') #' @return string with characters after separator clipped out
# ((74, 0), (74, 12), 'comment') #' @examples
# ((75, 0), (75, 67), 'comment') #' ClipLast("B6-13W1-BM-H3K4me3-1_269", jsep = "_", jsep.out = "_")
# ((76, 0), (76, 10), 'comment') #' @export
# ((77, 0), (77, 8), 'identifier') ClipLast
# ((77, 9), (77, 11), '<-') <-
# ((77, 12), (77, 20), 'function') function
# ((77, 20), (77, 21), '(') (
# ((77, 21), (77, 22), 'identifier') x
# ((77, 22), (77, 23), ',') ,
# ((77, 24), (77, 28), 'identifier') jsep
# ((77, 29), (77, 30), '=') =
# ((77, 31), (77, 34), 'string') "-"
# ((77, 34), (77, 35), ',') ,
# ((77, 36), (77, 44), 'identifier') jsep.out
# ((77, 45), (77, 46), '=') =
# ((77, 47), (77, 51), 'null') NULL
# ((77, 51), (77, 52), ')') )
# ((77, 52), (77, 53), '{') {
# ((78, 2), (78, 50), 'comment') # B6-13W1-BM-H3K4me3-1_269 -> B6-13W1-BM-H3K4me3
# ((79, 2), (79, 4), 'if') if
# ((79, 5), (79, 6), '(') (
# ((79, 6), (79, 13), 'identifier') is.null
# ((79, 13), (79, 14), '(') (
# ((79, 14), (79, 22), 'identifier') jsep.out
# ((79, 22), (79, 23), ')') )
# ((79, 23), (79, 24), ')') )
# ((79, 24), (79, 25), '{') {
# ((80, 4), (80, 12), 'identifier') jsep.out
# ((80, 13), (80, 15), '<-') <-
# ((80, 16), (80, 20), 'identifier') jsep
# ((80, 20), (81, 0), '\n')
# ((81, 2), (81, 3), '}') }
# ((81, 3), (82, 0), '\n')
# ((82, 2), (82, 8), 'identifier') jsplit
# ((82, 9), (82, 11), '<-') <-
# ((82, 12), (82, 20), 'identifier') strsplit
# ((82, 20), (82, 21), '(') (
# ((82, 21), (82, 22), 'identifier') x
# ((82, 22), (82, 23), ',') ,
# ((82, 24), (82, 28), 'identifier') jsep
# ((82, 28), (82, 29), ')') )
# ((82, 29), (82, 31), '[[') [[
# ((82, 31), (82, 32), 'float') 1
# ((82, 32), (82, 34), ']]') ]]
# ((82, 34), (83, 0), '\n')
# ((83, 2), (83, 19), 'comment') # remove last one
# ((84, 2), (84, 3), 'identifier') N
# ((84, 4), (84, 6), '<-') <-
# ((84, 7), (84, 13), 'identifier') length
# ((84, 13), (84, 14), '(') (
# ((84, 14), (84, 20), 'identifier') jsplit
# ((84, 20), (84, 21), ')') )
# ((84, 22), (84, 23), '-') -
# ((84, 24), (84, 25), 'float') 1
# ((84, 25), (85, 0), '\n')
# ((85, 2), (85, 8), 'identifier') return
# ((85, 8), (85, 9), '(') (
# ((85, 9), (85, 14), 'identifier') paste
# ((85, 14), (85, 15), '(') (
# ((85, 15), (85, 21), 'identifier') jsplit
# ((85, 21), (85, 22), '[') [
# ((85, 22), (85, 23), 'float') 1
# ((85, 23), (85, 24), ':') :
# ((85, 24), (85, 25), 'identifier') N
# ((85, 25), (85, 26), ']') ]
# ((85, 26), (85, 27), ',') ,
# ((85, 28), (85, 36), 'identifier') collapse
# ((85, 37), (85, 38), '=') =
# ((85, 39), (85, 47), 'identifier') jsep.out
# ((85, 47), (85, 48), ')') )
# ((85, 48), (85, 49), ')') )
# ((85, 49), (86, 0), '\n')
# ((86, 0), (86, 1), '}') }
# ((86, 1), (89, 0), '\n')
# ((89, 0), (89, 100), 'comment') #' Take softmax of a vector of values. Input are reals and output will be a vector of probabilities.
# ((90, 0), (90, 3), 'comment') #'
# ((91, 0), (91, 63), 'comment') #' @param x Vector of real numbers, can be negative or positive
# ((92, 0), (92, 56), 'comment') #' @param return.log Return the log of the probabilities
# ((93, 0), (93, 79), 'comment') #' @param logfn function for logarithm. Default natural log. Can also use log2.
# ((94, 0), (94, 39), 'comment') #' @return plog vector of probabilities
# ((95, 0), (95, 12), 'comment') #' @examples
# ((96, 0), (96, 102), 'comment') #' p.mat <- SoftMax(jfit$ll.mat)  # convert a vector of log-likelihoods into a vector of probabilities
# ((97, 0), (97, 10), 'comment') #' @export
# ((98, 0), (98, 7), 'identifier') SoftMax
# ((98, 8), (98, 10), '<-') <-
# ((98, 11), (98, 19), 'function') function
# ((98, 19), (98, 20), '(') (
# ((98, 20), (98, 21), 'identifier') x
# ((98, 21), (98, 22), ',') ,
# ((98, 23), (98, 33), 'identifier') return.log
# ((98, 34), (98, 35), '=') =
# ((98, 36), (98, 40), 'true') TRUE
# ((98, 40), (98, 41), ',') ,
# ((98, 42), (98, 47), 'identifier') logfn
# ((98, 48), (98, 49), '=') =
# ((98, 50), (98, 53), 'identifier') log
# ((98, 53), (98, 54), ')') )
# ((98, 54), (98, 55), '{') {
# ((99, 2), (99, 63), 'comment') # numericallys table softmax by subtracting the maximum first
# ((100, 2), (100, 75), 'comment') # https://stackoverflow.com/questions/42599498/numercially-stable-softmax
# ((101, 2), (101, 37), 'comment') # x value are in log if .log = TRUE
# ((102, 2), (102, 33), 'comment') # numer <- log(exp(x - max(x)))
# ((103, 2), (103, 38), 'comment') # denom <- log(sum(exp(x - max(x))))
# ((104, 2), (104, 7), 'identifier') numer
# ((104, 8), (104, 10), '<-') <-
# ((104, 11), (104, 16), 'identifier') logfn
# ((104, 16), (104, 17), '(') (
# ((104, 17), (104, 20), 'identifier') exp
# ((104, 20), (104, 21), '(') (
# ((104, 21), (104, 22), 'identifier') x
# ((104, 23), (104, 24), '-') -
# ((104, 25), (104, 28), 'identifier') max
# ((104, 28), (104, 29), '(') (
# ((104, 29), (104, 30), 'identifier') x
# ((104, 30), (104, 31), ')') )
# ((104, 31), (104, 32), ')') )
# ((104, 32), (104, 33), ')') )
# ((104, 33), (105, 0), '\n')
# ((105, 2), (105, 7), 'identifier') denom
# ((105, 8), (105, 10), '<-') <-
# ((105, 11), (105, 16), 'identifier') logfn
# ((105, 16), (105, 17), '(') (
# ((105, 17), (105, 20), 'identifier') sum
# ((105, 20), (105, 21), '(') (
# ((105, 21), (105, 24), 'identifier') exp
# ((105, 24), (105, 25), '(') (
# ((105, 25), (105, 26), 'identifier') x
# ((105, 27), (105, 28), '-') -
# ((105, 29), (105, 32), 'identifier') max
# ((105, 32), (105, 33), '(') (
# ((105, 33), (105, 34), 'identifier') x
# ((105, 34), (105, 35), ')') )
# ((105, 35), (105, 36), ')') )
# ((105, 36), (105, 37), ')') )
# ((105, 37), (105, 38), ')') )
# ((105, 38), (106, 0), '\n')
# ((106, 2), (106, 6), 'identifier') plog
# ((106, 7), (106, 9), '<-') <-
# ((106, 10), (106, 15), 'identifier') numer
# ((106, 16), (106, 17), '-') -
# ((106, 18), (106, 23), 'identifier') denom
# ((106, 23), (107, 0), '\n')
# ((107, 2), (107, 4), 'if') if
# ((107, 5), (107, 6), '(') (
# ((107, 6), (107, 16), 'identifier') return.log
# ((107, 16), (107, 17), ')') )
# ((107, 17), (107, 18), '{') {
# ((108, 4), (108, 10), 'identifier') return
# ((108, 10), (108, 11), '(') (
# ((108, 11), (108, 15), 'identifier') plog
# ((108, 15), (108, 16), ')') )
# ((108, 16), (109, 0), '\n')
# ((109, 2), (109, 3), '}') }
# ((109, 4), (109, 8), 'else') else
# ((109, 9), (109, 10), '{') {
# ((110, 4), (110, 10), 'identifier') return
# ((110, 10), (110, 11), '(') (
# ((110, 11), (110, 14), 'identifier') exp
# ((110, 14), (110, 15), '(') (
# ((110, 15), (110, 19), 'identifier') plog
# ((110, 19), (110, 20), ')') )
# ((110, 20), (110, 21), ')') )
# ((110, 21), (111, 0), '\n')
# ((111, 2), (111, 3), '}') }
# ((111, 3), (112, 0), '\n')
# ((112, 0), (112, 1), '}') }
# ((112, 1), (114, 0), '\n')
# C:/Users/shawn/Desktop/R/R/jakeyeung/scChIX/man/ConcatMat.Rd
# ['SimulationFunctions.R']
# ['ConcatMat', 'ConcatMat']
# C:/Users/shawn/Desktop/R/R/jakeyeung/scChIX/SimulationFunctions.R
# ((0, 0), (0, 12), 'comment') # Jake Yeung
# ((1, 0), (1, 30), 'comment') # Date of Creation: 2021-09-20
# ((2, 0), (2, 49), 'comment') # File: ~/projects/scChIX/R/SimulationFunctions.R
# ((3, 0), (3, 38), 'comment') # Functions for simulating scChIX data
# ((6, 0), (6, 128), 'comment') #' Wrangling function: Take count mat and summarize into mean across selected columns (eg by columns that are from same cluster)
# ((7, 0), (7, 3), 'comment') #'
# ((8, 0), (8, 78), 'comment') #' @param count.mat Count matrix, usually rows are genes and columns are cells
# ((9, 0), (9, 124), 'comment') #' @param cnames.keep.lst List where names are cluster identities, values in list are column names that are to be summarized
# ((10, 0), (10, 57), 'comment') #' @param jfunc Summarizing function, default is rowMeans
# ((11, 0), (11, 112), 'comment') #' @return List of count vectors with same names as cnames.keep.lst. Count values are across rows of the matrix
# ((12, 0), (12, 12), 'comment') #' @examples
# ((13, 0), (13, 139), 'comment') #' cnames.keep.lst <- lapply(split(dat.final.annots, f = dat.final.annots$cluster), function(x) x$cell) # create cluster to cell input list
# ((14, 0), (14, 129), 'comment') #' prob.mat.byclst.lst <- MeanAcrossClusters(prob.mat, cnames.keep.lst = cnames.keep.lst) # average probabilities across clusters
# ((15, 0), (15, 10), 'comment') #' @export
# ((16, 0), (16, 18), 'identifier') MeanAcrossClusters
# ((16, 19), (16, 21), '<-') <-
# ((16, 22), (16, 30), 'function') function
# ((16, 30), (16, 31), '(') (
# ((16, 31), (16, 40), 'identifier') count.mat
# ((16, 40), (16, 41), ',') ,
# ((16, 42), (16, 57), 'identifier') cnames.keep.lst
# ((16, 57), (16, 58), ',') ,
# ((16, 59), (16, 64), 'identifier') jfunc
# ((16, 65), (16, 66), '=') =
# ((16, 67), (16, 75), 'identifier') rowMeans
# ((16, 75), (16, 76), ')') )
# ((16, 76), (16, 77), '{') {
# ((17, 2), (17, 11), 'identifier') count.mat
# ((17, 12), (17, 14), '<-') <-
# ((17, 15), (17, 24), 'identifier') as.matrix
# ((17, 24), (17, 25), '(') (
# ((17, 25), (17, 34), 'identifier') count.mat
# ((17, 34), (17, 35), ')') )
# ((17, 35), (18, 0), '\n')
# ((18, 2), (18, 12), 'identifier') count.vecs
# ((18, 13), (18, 15), '<-') <-
# ((18, 16), (18, 22), 'identifier') lapply
# ((18, 22), (18, 23), '(') (
# ((18, 23), (18, 38), 'identifier') cnames.keep.lst
# ((18, 38), (18, 39), ',') ,
# ((18, 40), (18, 48), 'function') function
# ((18, 48), (18, 49), '(') (
# ((18, 49), (18, 60), 'identifier') cnames.keep
# ((18, 60), (18, 61), ')') )
# ((18, 61), (18, 62), '{') {
# ((19, 4), (19, 17), 'identifier') cnames.keep.i
# ((19, 18), (19, 20), '<-') <-
# ((19, 21), (19, 26), 'identifier') which
# ((19, 26), (19, 27), '(') (
# ((19, 27), (19, 35), 'identifier') colnames
# ((19, 35), (19, 36), '(') (
# ((19, 36), (19, 45), 'identifier') count.mat
# ((19, 45), (19, 46), ')') )
# ((19, 47), (19, 48), '%') %
# ((19, 50), (19, 51), '%') %
# ((19, 52), (19, 63), 'identifier') cnames.keep
# ((19, 63), (19, 64), ')') )
# ((19, 64), (20, 0), '\n')
# ((20, 4), (20, 14), 'identifier') assertthat
# ((20, 14), (20, 16), '::') ::
# ((20, 16), (20, 27), 'identifier') assert_that
# ((20, 27), (20, 28), '(') (
# ((20, 28), (20, 34), 'identifier') length
# ((20, 34), (20, 35), '(') (
# ((20, 35), (20, 48), 'identifier') cnames.keep.i
# ((20, 48), (20, 49), ')') )
# ((20, 50), (20, 51), '>') >
# ((20, 52), (20, 53), 'float') 0
# ((20, 53), (20, 54), ')') )
# ((20, 54), (21, 0), '\n')
# ((21, 4), (21, 9), 'identifier') jfunc
# ((21, 9), (21, 10), '(') (
# ((21, 10), (21, 19), 'identifier') count.mat
# ((21, 19), (21, 20), '[') [
# ((21, 20), (21, 21), ',') ,
# ((21, 22), (21, 35), 'identifier') cnames.keep.i
# ((21, 35), (21, 36), ']') ]
# ((21, 36), (21, 37), ')') )
# ((21, 37), (22, 0), '\n')
# ((22, 2), (22, 3), '}') }
# ((22, 3), (22, 4), ')') )
# ((22, 4), (23, 0), '\n')
# ((23, 2), (23, 8), 'identifier') return
# ((23, 8), (23, 9), '(') (
# ((23, 9), (23, 19), 'identifier') count.vecs
# ((23, 19), (23, 20), ')') )
# ((23, 20), (24, 0), '\n')
# ((24, 0), (24, 1), '}') }
# ((24, 1), (26, 0), '\n')
# ((26, 0), (26, 25), 'identifier') MergeMarksEstimateOverlap
# ((26, 26), (26, 28), '<-') <-
# ((26, 29), (26, 37), 'function') function
# ((26, 37), (26, 38), '(') (
# ((26, 38), (26, 45), 'identifier') bin.dat
# ((26, 45), (26, 46), ')') )
# ((26, 46), (26, 47), '{') {
# ((27, 2), (27, 46), 'comment') # bin.dat <- ctype.sim.counts.lst$A$bin.data
# ((28, 2), (28, 9), 'identifier') bin.dat
# ((28, 10), (28, 12), '<-') <-
# ((28, 13), (28, 20), 'identifier') bin.dat
# ((28, 20), (28, 21), '[') [
# ((28, 21), (28, 27), 'identifier') gtools
# ((28, 27), (28, 29), '::') ::
# ((28, 29), (28, 39), 'identifier') mixedorder
# ((28, 39), (28, 40), '(') (
# ((28, 40), (28, 47), 'identifier') bin.dat
# ((28, 47), (28, 48), '$') $
# ((28, 48), (28, 51), 'identifier') Bin
# ((28, 51), (28, 52), ')') )
# ((28, 52), (28, 53), ',') ,
# ((28, 54), (28, 55), ']') ]
# ((28, 55), (29, 0), '\n')
# ((29, 2), (29, 65), 'comment') # mat.prob <- mat.prob[, grepl(grepsuffix, colnames(mat.prob))]
# ((30, 2), (30, 84), 'comment') # mat.dbl <- mats$`mark1-mark2`[, grepl(grepsuffix, colnames(mats$`mark1-mark2`))]
# ((32, 2), (32, 29), 'comment') # compare with ground truth
# ((33, 2), (33, 8), 'identifier') jnbins
# ((33, 9), (33, 11), '<-') <-
# ((33, 12), (33, 16), 'identifier') nrow
# ((33, 16), (33, 17), '(') (
# ((33, 17), (33, 24), 'identifier') bin.dat
# ((33, 24), (33, 25), ')') )
# ((33, 25), (34, 0), '\n')
# ((34, 2), (34, 11), 'identifier') frac.swap
# ((34, 12), (34, 14), '<-') <-
# ((34, 15), (34, 31), 'identifier') ctype.params.lst
# ((34, 31), (34, 32), '$') $
# ((34, 32), (34, 33), 'identifier') A
# ((34, 33), (34, 34), '$') $
# ((34, 34), (34, 50), 'identifier') frac.mutual.excl
# ((34, 51), (34, 52), '/') /
# ((34, 53), (34, 54), 'float') 2
# ((34, 54), (35, 0), '\n')
# ((35, 2), (35, 13), 'identifier') bottom.bins
# ((35, 14), (35, 16), '<-') <-
# ((35, 17), (35, 18), '(') (
# ((35, 18), (35, 25), 'identifier') bin.dat
# ((35, 26), (35, 27), '%') %
# ((35, 28), (35, 29), '%') %
# ((35, 30), (35, 35), 'identifier') dplyr
# ((35, 35), (35, 37), '::') ::
# ((35, 37), (35, 44), 'identifier') arrange
# ((35, 44), (35, 45), '(') (
# ((35, 45), (35, 52), 'identifier') BinMean
# ((35, 52), (35, 53), ')') )
# ((35, 53), (35, 54), ')') )
# ((35, 54), (35, 55), '$') $
# ((35, 55), (35, 58), 'identifier') Bin
# ((35, 58), (35, 59), '[') [
# ((35, 59), (35, 60), 'float') 1
# ((35, 60), (35, 61), ':') :
# ((35, 61), (35, 62), '(') (
# ((35, 62), (35, 68), 'identifier') jnbins
# ((35, 69), (35, 70), '*') *
# ((35, 71), (35, 80), 'identifier') frac.swap
# ((35, 80), (35, 81), ')') )
# ((35, 81), (35, 82), ']') ]
# ((35, 82), (36, 0), '\n')
# ((36, 2), (36, 10), 'identifier') top.bins
# ((36, 11), (36, 13), '<-') <-
# ((36, 14), (36, 15), '(') (
# ((36, 15), (36, 22), 'identifier') bin.dat
# ((36, 23), (36, 24), '%') %
# ((36, 25), (36, 26), '%') %
# ((36, 27), (36, 32), 'identifier') dplyr
# ((36, 32), (36, 34), '::') ::
# ((36, 34), (36, 41), 'identifier') arrange
# ((36, 41), (36, 42), '(') (
# ((36, 42), (36, 46), 'identifier') desc
# ((36, 46), (36, 47), '(') (
# ((36, 47), (36, 54), 'identifier') BinMean
# ((36, 54), (36, 55), ')') )
# ((36, 55), (36, 56), ')') )
# ((36, 56), (36, 57), ')') )
# ((36, 57), (36, 58), '$') $
# ((36, 58), (36, 61), 'identifier') Bin
# ((36, 61), (36, 62), '[') [
# ((36, 62), (36, 63), 'float') 1
# ((36, 63), (36, 64), ':') :
# ((36, 64), (36, 65), '(') (
# ((36, 65), (36, 71), 'identifier') jnbins
# ((36, 72), (36, 73), '*') *
# ((36, 74), (36, 83), 'identifier') frac.swap
# ((36, 83), (36, 84), ')') )
# ((36, 84), (36, 85), ']') ]
# ((36, 85), (39, 0), '\n')
# ((39, 2), (39, 14), 'identifier') bin.means.A1
# ((39, 15), (39, 17), '<-') <-
# ((39, 18), (39, 28), 'identifier') data.frame
# ((39, 28), (39, 29), '(') (
# ((39, 29), (39, 33), 'identifier') mark
# ((39, 34), (39, 35), '=') =
# ((39, 36), (39, 43), 'string') "mark1"
# ((39, 43), (39, 44), ',') ,
# ((39, 45), (39, 52), 'identifier') BinMean
# ((39, 53), (39, 54), '=') =
# ((39, 55), (39, 62), 'identifier') bin.dat
# ((39, 62), (39, 63), '$') $
# ((39, 63), (39, 70), 'identifier') BinMean
# ((39, 70), (39, 71), ',') ,
# ((39, 72), (39, 77), 'identifier') annot
# ((39, 78), (39, 79), '=') =
# ((39, 80), (39, 87), 'identifier') bin.dat
# ((39, 87), (39, 88), '$') $
# ((39, 88), (39, 93), 'identifier') annot
# ((39, 93), (39, 94), ',') ,
# ((39, 95), (39, 111), 'identifier') stringsAsFactors
# ((39, 112), (39, 113), '=') =
# ((39, 114), (39, 119), 'false') FALSE
# ((39, 119), (39, 120), ')') )
# ((39, 120), (40, 0), '\n')
# ((40, 2), (40, 10), 'identifier') rownames
# ((40, 10), (40, 11), '(') (
# ((40, 11), (40, 23), 'identifier') bin.means.A1
# ((40, 23), (40, 24), ')') )
# ((40, 25), (40, 27), '<-') <-
# ((40, 28), (40, 35), 'identifier') bin.dat
# ((40, 35), (40, 36), '$') $
# ((40, 36), (40, 39), 'identifier') Bin
# ((40, 39), (42, 0), '\n')
# ((42, 2), (42, 14), 'identifier') bin.means.A2
# ((42, 15), (42, 17), '<-') <-
# ((42, 18), (42, 28), 'identifier') data.frame
# ((42, 28), (42, 29), '(') (
# ((42, 29), (42, 33), 'identifier') mark
# ((42, 34), (42, 35), '=') =
# ((42, 36), (42, 43), 'string') "mark2"
# ((42, 43), (42, 44), ',') ,
# ((42, 45), (42, 52), 'identifier') BinMean
# ((42, 53), (42, 54), '=') =
# ((42, 55), (42, 62), 'identifier') bin.dat
# ((42, 62), (42, 63), '$') $
# ((42, 63), (42, 70), 'identifier') BinMean
# ((42, 70), (42, 71), ',') ,
# ((42, 72), (42, 88), 'identifier') stringsAsFactors
# ((42, 89), (42, 90), '=') =
# ((42, 91), (42, 96), 'false') FALSE
# ((42, 96), (42, 97), ')') )
# ((42, 97), (43, 0), '\n')
# ((43, 2), (43, 10), 'identifier') rownames
# ((43, 10), (43, 11), '(') (
# ((43, 11), (43, 23), 'identifier') bin.means.A2
# ((43, 23), (43, 24), ')') )
# ((43, 25), (43, 27), '<-') <-
# ((43, 28), (43, 35), 'identifier') bin.dat
# ((43, 35), (43, 36), '$') $
# ((43, 36), (43, 39), 'identifier') Bin
# ((43, 39), (45, 0), '\n')
# ((45, 2), (45, 14), 'identifier') bin.means.A2
# ((45, 15), (45, 17), '<-') <-
# ((45, 18), (45, 24), 'identifier') scChIX
# ((45, 24), (45, 26), '::') ::
# ((45, 26), (45, 34), 'identifier') SwapBins
# ((45, 34), (45, 35), '(') (
# ((45, 35), (45, 54), 'identifier') ctype1.sim.counts.b
# ((45, 55), (45, 56), '=') =
# ((45, 57), (45, 69), 'identifier') bin.means.A2
# ((45, 69), (45, 70), ',') ,
# ((45, 71), (45, 79), 'identifier') top.bins
# ((45, 80), (45, 81), '=') =
# ((45, 82), (45, 90), 'identifier') top.bins
# ((45, 90), (45, 91), ',') ,
# ((45, 92), (45, 103), 'identifier') bottom.bins
# ((45, 104), (45, 105), '=') =
# ((45, 106), (45, 117), 'identifier') bottom.bins
# ((45, 117), (45, 118), ',') ,
# ((45, 119), (45, 128), 'identifier') frac.swap
# ((45, 129), (45, 130), '=') =
# ((45, 131), (45, 140), 'identifier') frac.swap
# ((45, 140), (45, 141), ')') )
# ((45, 141), (47, 0), '\n')
# ((47, 2), (47, 14), 'identifier') bin.means.A1
# ((47, 14), (47, 15), '$') $
# ((47, 15), (47, 18), 'identifier') Bin
# ((47, 19), (47, 21), '<-') <-
# ((47, 22), (47, 30), 'identifier') rownames
# ((47, 30), (47, 31), '(') (
# ((47, 31), (47, 43), 'identifier') bin.means.A1
# ((47, 43), (47, 44), ')') )
# ((47, 44), (48, 0), '\n')
# ((48, 2), (48, 14), 'identifier') bin.means.A2
# ((48, 14), (48, 15), '$') $
# ((48, 15), (48, 18), 'identifier') Bin
# ((48, 19), (48, 21), '<-') <-
# ((48, 22), (48, 30), 'identifier') rownames
# ((48, 30), (48, 31), '(') (
# ((48, 31), (48, 43), 'identifier') bin.means.A2
# ((48, 43), (48, 44), ')') )
# ((48, 44), (50, 0), '\n')
# ((50, 2), (50, 20), 'identifier') bin.means.A.merged
# ((50, 21), (50, 23), '<-') <-
# ((50, 24), (50, 33), 'identifier') left_join
# ((50, 33), (50, 34), '(') (
# ((50, 34), (50, 46), 'identifier') bin.means.A1
# ((50, 46), (50, 47), ',') ,
# ((50, 48), (50, 60), 'identifier') bin.means.A2
# ((50, 60), (50, 61), ',') ,
# ((50, 62), (50, 64), 'identifier') by
# ((50, 65), (50, 66), '=') =
# ((50, 67), (50, 72), 'string') "Bin"
# ((50, 72), (50, 73), ')') )
# ((50, 74), (50, 75), '%') %
# ((50, 76), (50, 77), '%') %
# ((51, 4), (51, 11), 'identifier') rowwise
# ((51, 11), (51, 12), '(') (
# ((51, 12), (51, 13), ')') )
# ((51, 14), (51, 15), '%') %
# ((51, 16), (51, 17), '%') %
# ((52, 4), (52, 10), 'identifier') mutate
# ((52, 10), (52, 11), '(') (
# ((52, 11), (52, 22), 'identifier') BinMean.dbl
# ((52, 23), (52, 24), '=') =
# ((52, 25), (52, 26), '(') (
# ((52, 26), (52, 35), 'identifier') BinMean.x
# ((52, 35), (52, 36), ')') )
# ((52, 37), (52, 38), '/') /
# ((52, 39), (52, 40), '(') (
# ((52, 40), (52, 49), 'identifier') BinMean.x
# ((52, 50), (52, 51), '+') +
# ((52, 52), (52, 61), 'identifier') BinMean.y
# ((52, 61), (52, 62), ')') )
# ((52, 62), (52, 63), ')') )
# ((52, 63), (53, 0), '\n')
# ((53, 2), (53, 8), 'identifier') return
# ((53, 8), (53, 9), '(') (
# ((53, 9), (53, 27), 'identifier') bin.means.A.merged
# ((53, 27), (53, 28), ')') )
# ((53, 28), (54, 0), '\n')
# ((54, 0), (54, 1), '}') }
# ((54, 1), (57, 0), '\n')
# ((57, 0), (57, 118), 'comment') #' Wrangling function: Takes different cell types from a histone mark X SimulateChICseq and concatenates them together
# ((58, 0), (58, 3), 'comment') #'
# ((59, 0), (59, 137), 'comment') #' @param ctype.sim.counts.lst Output from SimulateChICseq which contains different cell types across different histone mark conditions.
# ((60, 0), (60, 75), 'comment') #' @param ctypes Vector of name of cell types to be concatenated together.
# ((61, 0), (61, 77), 'comment') #' @param jmark Name of histone mark from which cell types will be extracted.
# ((62, 0), (62, 72), 'comment') #' @return mat.mark1 Matrix of counts, rows are bins, columns are cells.
# ((63, 0), (63, 12), 'comment') #' @examples
# ((64, 0), (64, 59), 'comment') #' ctype.sim.counts.lst <- lapply(ctypes, function(jctype){
# ((65, 0), (65, 39), 'comment') #' SimulateChICseq(ctype.name = jctype,
# ((66, 0), (66, 60), 'comment') #'                 jseed = ctype.params.lst[[jctype]]$jseed,
# ((67, 0), (67, 84), 'comment') #'                 shuffle.rows.seed = ctype.params.lst[[jctype]]$shuffle.rows.seed,
# ((68, 0), (68, 82), 'comment') #'                 frac.mutual.excl = ctype.params.lst[[jctype]]$frac.mutual.excl)
# ((69, 0), (69, 5), 'comment') #' })
# ((70, 0), (70, 72), 'comment') #' mat.mark1 <- ConcatMat(ctype.sim.counts.lst, ctypes, jmark = "mark1")
# ((71, 0), (71, 10), 'comment') #' @export
# ((72, 0), (72, 9), 'identifier') ConcatMat
# ((72, 10), (72, 12), '<-') <-
# ((72, 13), (72, 21), 'function') function
# ((72, 21), (72, 22), '(') (
# ((72, 22), (72, 42), 'identifier') ctype.sim.counts.lst
# ((72, 42), (72, 43), ',') ,
# ((72, 44), (72, 50), 'identifier') ctypes
# ((72, 50), (72, 51), ',') ,
# ((72, 52), (72, 57), 'identifier') jmark
# ((72, 57), (72, 58), ')') )
# ((72, 58), (72, 59), '{') {
# ((73, 2), (73, 15), 'identifier') mat.mark1.lst
# ((73, 16), (73, 18), '<-') <-
# ((73, 19), (73, 25), 'identifier') lapply
# ((73, 25), (73, 26), '(') (
# ((73, 26), (73, 32), 'identifier') ctypes
# ((73, 32), (73, 33), ',') ,
# ((73, 34), (73, 42), 'function') function
# ((73, 42), (73, 43), '(') (
# ((73, 43), (73, 49), 'identifier') jctype
# ((73, 49), (73, 50), ')') )
# ((73, 50), (73, 51), '{') {
# ((74, 4), (74, 24), 'identifier') ctype.sim.counts.lst
# ((74, 24), (74, 26), '[[') [[
# ((74, 26), (74, 32), 'identifier') jctype
# ((74, 32), (74, 34), ']]') ]]
# ((74, 34), (74, 36), '[[') [[
# ((74, 36), (74, 41), 'identifier') jmark
# ((74, 41), (74, 43), ']]') ]]
# ((74, 43), (75, 0), '\n')
# ((75, 2), (75, 3), '}') }
# ((75, 3), (75, 4), ')') )
# ((75, 4), (76, 0), '\n')
# ((76, 2), (76, 15), 'identifier') rnames.common
# ((76, 16), (76, 18), '<-') <-
# ((76, 19), (76, 25), 'identifier') unique
# ((76, 25), (76, 26), '(') (
# ((76, 26), (76, 32), 'identifier') gtools
# ((76, 32), (76, 34), '::') ::
# ((76, 34), (76, 43), 'identifier') mixedsort
# ((76, 43), (76, 44), '(') (
# ((76, 44), (76, 50), 'identifier') unlist
# ((76, 50), (76, 51), '(') (
# ((76, 51), (76, 57), 'identifier') lapply
# ((76, 57), (76, 58), '(') (
# ((76, 58), (76, 71), 'identifier') mat.mark1.lst
# ((76, 71), (76, 72), ',') ,
# ((76, 73), (76, 81), 'identifier') rownames
# ((76, 81), (76, 82), ')') )
# ((76, 82), (76, 83), ')') )
# ...
# ((44, 0), (44, 153), 'comment') #' @return if return.mat=TRUE, returns full log-likelihood matrix for all possible pairs. If False, returns the negative of the maximum likelihood value.
# ((45, 0), (45, 12), 'comment') #' @examples
# ((46, 0), (46, 29), 'comment') #' data(RawDblCountMatSubset)
# ((47, 0), (47, 87), 'comment') #' cell.count.raw.merged.lst <- as.list(as.data.frame(as.matrix(count.mat.dbl.subset)))
# ((48, 0), (48, 94), 'comment') #' act.repress.coord.lst <- lapply(cell.count.raw.merged.lst, function(cell.count.raw.merged){
# ((49, 0), (49, 80), 'comment') #'   optim.out <- FitMixingWeight(cell.count.raw.merged = cell.count.raw.merged,
# ((50, 0), (50, 82), 'comment') #'                                dat.impute.repress.lst = dat.impute.repress.lst,
# ((51, 0), (51, 141), 'comment') #'                                dat.impute.active = dat.impute.active, w.init = 0.5, w.lower = wlower, w.upper = wupper, jmethod = "Brent")
# ((52, 0), (52, 126), 'comment') #'   ll.mat <- GetLLMerged(optim.out$par, cell.count.raw.merged, dat.impute.repress.lst, dat.impute.active, return.mat = TRUE)
# ((53, 0), (53, 53), 'comment') #'   return(list(ll.mat = ll.mat, w = optim.out$par))
# ((54, 0), (54, 5), 'comment') #' })
# ((55, 0), (55, 10), 'comment') #' @export
# ((56, 0), (56, 11), 'identifier') GetLLMerged
# ((56, 12), (56, 14), '<-') <-
# ((56, 15), (56, 23), 'function') function
# ((56, 23), (56, 24), '(') (
# ((56, 24), (56, 25), 'identifier') w
# ((56, 25), (56, 26), ',') ,
# ((56, 27), (56, 48), 'identifier') cell.count.raw.merged
# ((56, 48), (56, 49), ',') ,
# ((56, 50), (56, 72), 'identifier') dat.impute.repress.lst
# ((56, 72), (56, 73), ',') ,
# ((56, 74), (56, 91), 'identifier') dat.impute.active
# ((56, 91), (56, 92), ',') ,
# ((56, 93), (56, 103), 'identifier') return.mat
# ((56, 104), (56, 105), '=') =
# ((56, 106), (56, 111), 'false') FALSE
# ((56, 111), (56, 112), ')') )
# ((56, 112), (56, 113), '{') {
# ((57, 2), (57, 7), 'identifier') w.vec
# ((57, 8), (57, 10), '<-') <-
# ((57, 11), (57, 12), 'identifier') c
# ((57, 12), (57, 13), '(') (
# ((57, 13), (57, 14), 'identifier') w
# ((57, 14), (57, 15), ',') ,
# ((57, 16), (57, 17), 'float') 1
# ((57, 17), (57, 18), '-') -
# ((57, 18), (57, 19), 'identifier') w
# ((57, 19), (57, 20), ')') )
# ((57, 22), (57, 61), 'comment') # active proportion, repress proportion
# ((57, 61), (58, 0), '\n')
# ((58, 2), (58, 4), 'if') if
# ((58, 5), (58, 6), '(') (
# ((58, 6), (58, 9), 'identifier') any
# ((58, 9), (58, 10), '(') (
# ((58, 10), (58, 15), 'identifier') w.vec
# ((58, 16), (58, 17), '<') <
# ((58, 18), (58, 19), 'float') 0
# ((58, 19), (58, 20), ')') )
# ((58, 20), (58, 21), ')') )
# ((58, 21), (58, 22), '{') {
# ((59, 4), (59, 9), 'identifier') print
# ((59, 9), (59, 10), '(') (
# ((59, 10), (59, 15), 'identifier') paste
# ((59, 15), (59, 16), '(') (
# ((59, 16), (59, 47), 'string') "Error message: w is negative:"
# ((59, 47), (59, 48), ')') )
# ((59, 48), (59, 49), ')') )
# ((59, 49), (60, 0), '\n')
# ((60, 4), (60, 9), 'identifier') print
# ((60, 9), (60, 10), '(') (
# ((60, 10), (60, 15), 'identifier') w.vec
# ((60, 15), (60, 16), ')') )
# ((60, 16), (61, 0), '\n')
# ((61, 4), (61, 9), 'identifier') w.vec
# ((61, 9), (61, 10), '[') [
# ((61, 10), (61, 19), 'identifier') which.min
# ((61, 19), (61, 20), '(') (
# ((61, 20), (61, 25), 'identifier') w.vec
# ((61, 25), (61, 26), ')') )
# ((61, 26), (61, 27), ']') ]
# ((61, 28), (61, 30), '<-') <-
# ((61, 31), (61, 32), 'float') 0
# ((61, 32), (62, 0), '\n')
# ((62, 4), (62, 9), 'identifier') w.vec
# ((62, 9), (62, 10), '[') [
# ((62, 10), (62, 19), 'identifier') which.max
# ((62, 19), (62, 20), '(') (
# ((62, 20), (62, 25), 'identifier') w.vec
# ((62, 25), (62, 26), ')') )
# ((62, 26), (62, 27), ']') ]
# ((62, 28), (62, 30), '<-') <-
# ((62, 31), (62, 32), 'float') 1
# ((62, 32), (63, 0), '\n')
# ((63, 4), (63, 9), 'identifier') print
# ((63, 9), (63, 10), '(') (
# ((63, 10), (63, 20), 'string') "Fixed w:"
# ((63, 20), (63, 21), ')') )
# ((63, 21), (64, 0), '\n')
# ((64, 4), (64, 9), 'identifier') print
# ((64, 9), (64, 10), '(') (
# ((64, 10), (64, 15), 'identifier') w.vec
# ((64, 15), (64, 16), ')') )
# ((64, 16), (65, 0), '\n')
# ((65, 2), (65, 3), '}') }
# ((65, 3), (66, 0), '\n')
# ((66, 2), (66, 20), 'identifier') dat.imputed.merged
# ((66, 21), (66, 23), '<-') <-
# ((66, 24), (66, 30), 'identifier') lapply
# ((66, 30), (66, 31), '(') (
# ((66, 31), (66, 53), 'identifier') dat.impute.repress.lst
# ((66, 53), (66, 54), ',') ,
# ((66, 55), (66, 63), 'function') function
# ((66, 63), (66, 64), '(') (
# ((66, 64), (66, 75), 'identifier') repress.row
# ((66, 75), (66, 76), ')') )
# ((66, 76), (66, 77), '{') {
# ((67, 4), (67, 5), 'identifier') t
# ((67, 5), (67, 6), '(') (
# ((67, 6), (67, 12), 'identifier') outmat
# ((67, 13), (67, 15), '<-') <-
# ((67, 16), (67, 21), 'identifier') apply
# ((67, 21), (67, 22), '(') (
# ((67, 22), (67, 39), 'identifier') dat.impute.active
# ((67, 39), (67, 40), ',') ,
# ((67, 41), (67, 42), 'float') 1
# ((67, 42), (67, 43), ',') ,
# ((67, 44), (67, 52), 'function') function
# ((67, 52), (67, 53), '(') (
# ((67, 53), (67, 60), 'identifier') act.row
# ((67, 60), (67, 61), ')') )
# ((67, 61), (67, 62), '{') {
# ((68, 6), (68, 17), 'identifier') matrixStats
# ((68, 17), (68, 19), '::') ::
# ((68, 19), (68, 35), 'identifier') colWeightedMeans
# ((68, 35), (68, 36), '(') (
# ((68, 36), (68, 41), 'identifier') rbind
# ((68, 41), (68, 42), '(') (
# ((68, 42), (68, 49), 'identifier') act.row
# ((68, 49), (68, 50), ',') ,
# ((68, 51), (68, 62), 'identifier') repress.row
# ((68, 62), (68, 63), ')') )
# ((68, 63), (68, 64), ',') ,
# ((68, 65), (68, 66), 'identifier') w
# ((68, 67), (68, 68), '=') =
# ((68, 69), (68, 74), 'identifier') w.vec
# ((68, 74), (68, 75), ')') )
# ((68, 77), (68, 115), 'comment') # standard weighted.mean is SUPER slow
# ((68, 115), (69, 0), '\n')
# ((69, 4), (69, 5), '}') }
# ((69, 5), (69, 6), ')') )
# ((69, 6), (69, 7), ')') )
# ((69, 7), (70, 0), '\n')
# ((70, 2), (70, 3), '}') }
# ((70, 3), (70, 4), ')') )
# ((70, 4), (71, 0), '\n')
# ((71, 2), (71, 77), 'comment') # Calculate all the likelihoods  ------------------------------------------
# ((72, 2), (72, 50), 'comment') # output will be N active cell by N repress cell
# ((73, 2), (73, 15), 'identifier') repress.names
# ((73, 16), (73, 18), '<-') <-
# ((73, 19), (73, 24), 'identifier') names
# ((73, 24), (73, 25), '(') (
# ((73, 25), (73, 43), 'identifier') dat.imputed.merged
# ((73, 43), (73, 44), ')') )
# ((73, 44), (74, 0), '\n')
# ((74, 2), (74, 7), 'identifier') names
# ((74, 7), (74, 8), '(') (
# ((74, 8), (74, 21), 'identifier') repress.names
# ((74, 21), (74, 22), ')') )
# ((74, 23), (74, 25), '<-') <-
# ((74, 26), (74, 39), 'identifier') repress.names
# ((74, 39), (76, 0), '\n')
# ((76, 2), (76, 8), 'identifier') ll.lst
# ((76, 9), (76, 11), '<-') <-
# ((76, 12), (76, 18), 'identifier') lapply
# ((76, 18), (76, 19), '(') (
# ((76, 19), (76, 32), 'identifier') repress.names
# ((76, 32), (76, 33), ',') ,
# ((76, 34), (76, 42), 'function') function
# ((76, 42), (76, 43), '(') (
# ((76, 43), (76, 55), 'identifier') repress.name
# ((76, 55), (76, 56), ')') )
# ((76, 56), (76, 57), '{') {
# ((77, 4), (77, 15), 'identifier') repress.mat
# ((77, 16), (77, 18), '<-') <-
# ((77, 19), (77, 37), 'identifier') dat.imputed.merged
# ((77, 37), (77, 39), '[[') [[
# ((77, 39), (77, 51), 'identifier') repress.name
# ((77, 51), (77, 53), ']]') ]]
# ((77, 53), (78, 0), '\n')
# ((78, 4), (78, 6), 'identifier') ll
# ((78, 7), (78, 9), '<-') <-
# ((78, 10), (78, 23), 'identifier') as.data.frame
# ((78, 23), (78, 24), '(') (
# ((78, 24), (78, 29), 'identifier') apply
# ((78, 29), (78, 30), '(') (
# ((78, 30), (78, 41), 'identifier') repress.mat
# ((78, 41), (78, 42), ',') ,
# ((78, 43), (78, 44), 'float') 1
# ((78, 44), (78, 45), ',') ,
# ((78, 46), (78, 54), 'function') function
# ((78, 54), (78, 55), '(') (
# ((78, 55), (78, 70), 'identifier') merged.prob.vec
# ((78, 70), (78, 71), ')') )
# ((78, 71), (78, 72), '{') {
# ((79, 6), (79, 12), 'identifier') return
# ((79, 12), (79, 13), '(') (
# ((79, 13), (79, 22), 'identifier') dmultinom
# ((79, 22), (79, 23), '(') (
# ((79, 23), (79, 24), 'identifier') x
# ((79, 25), (79, 26), '=') =
# ((79, 27), (79, 48), 'identifier') cell.count.raw.merged
# ((79, 48), (79, 49), ',') ,
# ((79, 50), (79, 54), 'identifier') prob
# ((79, 55), (79, 56), '=') =
# ((79, 57), (79, 72), 'identifier') merged.prob.vec
# ((79, 72), (79, 73), ',') ,
# ((79, 74), (79, 77), 'identifier') log
# ((79, 78), (79, 79), '=') =
# ((79, 80), (79, 84), 'true') TRUE
# ((79, 84), (79, 85), ')') )
# ((79, 85), (79, 86), ')') )
# ((79, 86), (80, 0), '\n')
# ((80, 4), (80, 5), '}') }
# ((80, 5), (80, 6), ')') )
# ((80, 6), (80, 7), ')') )
# ((80, 7), (81, 0), '\n')
# ((81, 4), (81, 12), 'identifier') rownames
# ((81, 12), (81, 13), '(') (
# ((81, 13), (81, 15), 'identifier') ll
# ((81, 15), (81, 16), ')') )
# ((81, 17), (81, 19), '<-') <-
# ((81, 20), (81, 28), 'identifier') rownames
# ((81, 28), (81, 29), '(') (
# ((81, 29), (81, 40), 'identifier') repress.mat
# ((81, 40), (81, 41), ')') )
# ((81, 41), (82, 0), '\n')
# ((82, 4), (82, 12), 'identifier') colnames
# ((82, 12), (82, 13), '(') (
# ((82, 13), (82, 15), 'identifier') ll
# ((82, 15), (82, 16), ')') )
# ((82, 17), (82, 19), '<-') <-
# ((82, 20), (82, 32), 'identifier') repress.name
# ((82, 32), (83, 0), '\n')
# ((83, 4), (83, 10), 'identifier') return
# ((83, 10), (83, 11), '(') (
# ((83, 11), (83, 13), 'identifier') ll
# ((83, 13), (83, 14), ')') )
# ((83, 14), (84, 0), '\n')
# ((84, 4), (84, 25), 'comment') # return(repress.mat)
# ((85, 2), (85, 3), '}') }
# ((85, 3), (85, 4), ')') )
# ((85, 4), (86, 0), '\n')
# ((86, 2), (86, 11), 'identifier') ll.merged
# ((86, 12), (86, 14), '<-') <-
# ((86, 15), (86, 22), 'identifier') do.call
# ((86, 22), (86, 23), '(') (
# ((86, 23), (86, 28), 'identifier') cbind
# ((86, 28), (86, 29), ',') ,
# ((86, 30), (86, 36), 'identifier') ll.lst
# ((86, 36), (86, 37), ')') )
# ((86, 37), (87, 0), '\n')
# ((87, 2), (87, 4), 'if') if
# ((87, 5), (87, 6), '(') (
# ((87, 6), (87, 16), 'identifier') return.mat
# ((87, 16), (87, 17), ')') )
# ((87, 17), (87, 18), '{') {
# ((88, 4), (88, 10), 'identifier') return
# ((88, 10), (88, 11), '(') (
# ((88, 11), (88, 20), 'identifier') ll.merged
# ((88, 20), (88, 21), ')') )
# ((88, 21), (89, 0), '\n')
# ((89, 2), (89, 3), '}') }
# ((89, 4), (89, 8), 'else') else
# ((89, 9), (89, 10), '{') {
# ((90, 4), (90, 43), 'comment') # return negative of maximum likelihood
# ((91, 4), (91, 47), 'comment') # negative because optimizers find minimums
# ((92, 4), (92, 10), 'identifier') return
# ((92, 10), (92, 11), '(') (
# ((92, 11), (92, 12), '-') -
# ((92, 12), (92, 13), 'float') 1
# ((92, 14), (92, 15), '*') *
# ((92, 16), (92, 19), 'identifier') max
# ((92, 19), (92, 20), '(') (
# ((92, 20), (92, 29), 'identifier') ll.merged
# ((92, 29), (92, 30), ')') )
# ((92, 30), (92, 31), ')') )
# ((92, 31), (93, 0), '\n')
# ((93, 2), (93, 3), '}') }
# ((93, 3), (94, 0), '\n')
# ((94, 0), (94, 1), '}') }
# ((94, 1), (97, 0), '\n')
# ((97, 0), (97, 105), 'comment') #' Infer best pair of clusters from a double-incubated cell that maximizes the multinomial log-likelihood
# ((98, 0), (98, 3), 'comment') #'
# ((99, 0), (99, 88), 'comment') #' @param cell.count.raw.merged vector of raw cell counts from a double-incubated cell.
# ((100, 0), (100, 229), 'comment') #' @param dat.impute.repress.lst Non-reference histone modification: list object containing cluster-specific probability weights across genomic bins. Each element in list is a probability vector across genomic bins for a cluster.
# ((101, 0), (101, 187), 'comment') #' @param dat.impute.active Reference histone modification: matrix object where rows are cluster names and columns are genomic bins. Each row is a probability vector across genomic bins.
# ((102, 0), (102, 160), 'comment') #' @param w.init initial guess for the mixing fraction between the two histone modifications. Mixing fraction is relative to the reference histone modification.
# ((103, 0), (103, 60), 'comment') #' @param w.lower lower bound for mixing weights, usually 0.
# ((104, 0), (104, 60), 'comment') #' @param w.upper lower bound for mixing weights, usually 1.
# ((105, 0), (105, 101), 'comment') #' @param jmethod method for optimizing w. Use "Brent" because it is a 1D problem given two clusters.
# ((106, 0), (106, 139), 'comment') #' @return optim output for best pair of clusters (one from an element in dat.impute.repress.lst, other from a row from dat.impute.active).
# ((107, 0), (107, 12), 'comment') #' @examples
# ((108, 0), (108, 29), 'comment') #' data(RawDblCountMatSubset)
# ((109, 0), (109, 87), 'comment') #' cell.count.raw.merged.lst <- as.list(as.data.frame(as.matrix(count.mat.dbl.subset)))
# ((110, 0), (110, 94), 'comment') #' act.repress.coord.lst <- lapply(cell.count.raw.merged.lst, function(cell.count.raw.merged){
# ((111, 0), (111, 80), 'comment') #'   optim.out <- FitMixingWeight(cell.count.raw.merged = cell.count.raw.merged,
# ((112, 0), (112, 82), 'comment') #'                                dat.impute.repress.lst = dat.impute.repress.lst,
# ((113, 0), (113, 141), 'comment') #'                                dat.impute.active = dat.impute.active, w.init = 0.5, w.lower = wlower, w.upper = wupper, jmethod = "Brent")
# ((114, 0), (114, 126), 'comment') #'   ll.mat <- GetLLMerged(optim.out$par, cell.count.raw.merged, dat.impute.repress.lst, dat.impute.active, return.mat = TRUE)
# ((115, 0), (115, 53), 'comment') #'   return(list(ll.mat = ll.mat, w = optim.out$par))
# ((116, 0), (116, 5), 'comment') #' })
# ((117, 0), (117, 10), 'comment') #' @export
# ((118, 0), (118, 15), 'identifier') FitMixingWeight
# ((118, 16), (118, 18), '<-') <-
# ((118, 19), (118, 27), 'function') function
# ((118, 27), (118, 28), '(') (
# ((118, 28), (118, 49), 'identifier') cell.count.raw.merged
# ((118, 49), (118, 50), ',') ,
# ((118, 51), (118, 73), 'identifier') dat.impute.repress.lst
# ((118, 73), (118, 74), ',') ,
# ((118, 75), (118, 92), 'identifier') dat.impute.active
# ((118, 92), (118, 93), ',') ,
# ((118, 94), (118, 100), 'identifier') w.init
# ((118, 100), (118, 101), ',') ,
# ((118, 102), (118, 109), 'identifier') w.lower
# ((118, 109), (118, 110), ',') ,
# ((118, 111), (118, 118), 'identifier') w.upper
# ((118, 118), (118, 119), ',') ,
# ((118, 120), (118, 127), 'identifier') jmethod
# ((118, 128), (118, 129), '=') =
# ((118, 130), (118, 137), 'string') "Brent"
# ((118, 137), (118, 138), ')') )
# ((118, 138), (118, 139), '{') {
# ((119, 2), (119, 87), 'comment') # https://www.psychologie.uni-heidelberg.de/ae/meth/team/mertens/blog/hessian.nb.html
# ((120, 2), (120, 35), 'comment') # method by Brent is recommended?
# ((121, 2), (121, 27), 'comment') # jmethod <- ""L-BFGS-B""
# ((122, 2), (122, 7), 'identifier') optim
# ((122, 7), (122, 8), '(') (
# ((122, 8), (122, 11), 'identifier') par
# ((122, 12), (122, 13), '=') =
# ((122, 14), (122, 20), 'identifier') w.init
# ((122, 20), (122, 21), ',') ,
# ((123, 8), (123, 10), 'identifier') fn
# ((123, 11), (123, 12), '=') =
# ((123, 13), (123, 24), 'identifier') GetLLMerged
# ((123, 24), (123, 25), ',') ,
# ((124, 8), (124, 29), 'identifier') cell.count.raw.merged
# ((124, 30), (124, 31), '=') =
# ((124, 32), (124, 53), 'identifier') cell.count.raw.merged
# ((124, 53), (124, 54), ',') ,
# ((125, 8), (125, 30), 'identifier') dat.impute.repress.lst
# ((125, 31), (125, 32), '=') =
# ((125, 33), (125, 55), 'identifier') dat.impute.repress.lst
# ((125, 55), (125, 56), ',') ,
# ((126, 8), (126, 25), 'identifier') dat.impute.active
# ((126, 26), (126, 27), '=') =
# ((126, 28), (126, 45), 'identifier') dat.impute.active
# ((126, 45), (126, 46), ',') ,
# ((127, 8), (127, 14), 'identifier') method
# ((127, 15), (127, 16), '=') =
# ((127, 17), (127, 24), 'identifier') jmethod
# ((127, 24), (127, 25), ',') ,
# ((127, 26), (127, 33), 'identifier') hessian
# ((127, 33), (127, 34), '=') =
# ((127, 34), (127, 38), 'true') TRUE
# ((127, 38), (127, 39), ',') ,
# ((127, 40), (127, 45), 'identifier') lower
# ((127, 46), (127, 47), '=') =
# ((127, 48), (127, 55), 'identifier') w.lower
# ((127, 55), (127, 56), ',') ,
# ((127, 57), (127, 62), 'identifier') upper
# ((127, 63), (127, 64), '=') =
# ((127, 65), (127, 72), 'identifier') w.upper
# ((127, 72), (127, 73), ')') )
# ((127, 73), (128, 0), '\n')
# ((128, 0), (128, 1), '}') }
# ((128, 1), (129, 0), '\n')
